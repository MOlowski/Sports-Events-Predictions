# %% [markdown]
# # 1. Insert countries data into postgresql

# %%
import pandas as pd

cs = pd.read_csv('data/countries.csv')
eur_s = pd.read_csv('data/european_seasons.csv')
s = pd.read_csv('data/seasons.csv')

# %%
cs.head()
# Out:
#                   name code                                      logo
# 0              Albania   AL  https://media.api-sports.io/flags/al.svg
# 1              Algeria   DZ  https://media.api-sports.io/flags/dz.svg
# 2              Andorra   AD  https://media.api-sports.io/flags/ad.svg
# 3               Angola   AO  https://media.api-sports.io/flags/ao.svg
# 4  Antigua-And-Barbuda   AG  https://media.api-sports.io/flags/ag.svg

# %%
import psycopg2

db_params = {
    'host': 'localhost',
    'database': 'preds',
    'user': 'postgres',
    'password': 'pass',
    'port': '5432'
}

try:
    conn = None
    cur = None 

    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    insert_query = """
        INSERT INTO {} ({})
        VALUES ({})
    """.format('countries', ','.join(cs.columns), ','.join(['%s']*len(cs.columns)))

    cur.executemany(insert_query, cs.values.tolist())
    print('inserted')
    conn.commit()
except Exception as e:
    print(f'Error {e}')

finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()
# Out:
# inserted

# %% [markdown]
# ##### changed foreign key

# %%
import psycopg2

db_params = {
    'host': 'localhost',
    'database': 'preds',
    'user': 'postgres',
    'password': 'pass',
    'port': '5432'
}

try:
    conn = None
    cur = None 

    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    drop_constraint_query = """
    ALTER TABLE team_stats
    DROP CONSTRAINT IF EXISTS fk_stats_team;
    """
    cur.execute(drop_constraint_query)
    conn.commit()
    print('Dropped existing foreign key constraint')
    
    
    # Step 2: Add the new foreign key constraint
    add_constraint_query = """
    ALTER TABLE teams
    ADD CONSTRAINT fk_team_country
    FOREIGN KEY (team_country) REFERENCES countries(name);
    """
    cur.execute(drop_constraint_query)
    conn.commit()
    print('Added new foreign key constraint')
    conn.commit()
    

except Exception as e:
    print(f'Error {e}')

finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()
# Out:
# Dropped existing foreign key constraint
# Added new foreign key constraint

# %% [markdown]
# ##### change col type

# %%
import psycopg2

db_params = {
    'host': 'localhost',
    'database': 'preds',
    'user': 'postgres',
    'password': 'pass',
    'port': '5432'
}

try:
    conn = None
    cur = None 

    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    drop_constraint_query = """
    ALTER TABLE fixture_statistics
    RENAME COLUMN id TO fixture_id;
    """
    cur.execute(drop_constraint_query)
    conn.commit()
    print('changed col type')

except Exception as e:
    print(f'Error {e}')

finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()
# Out:
# changed col type

# %% [markdown]
# # Insert league data to postgresql

# %%
c = pd.read_csv('data/contests.csv')
c.head()
# Out:
#    league_id                name    type  \
# 0          4   Euro Championship     Cup
# 1         21  Confederations Cup     Cup
# 2         61             Ligue 1  League
# 3        144  Jupiler Pro League  League
# 4         71             Serie A  League
#
#                                                 logo  country country_code  \
# 0  https://media.api-sports.io/football/leagues/4...    World          NaN
# 1  https://media.api-sports.io/football/leagues/2...    World          NaN
# 2  https://media.api-sports.io/football/leagues/6...   France           FR
# 3  https://media.api-sports.io/football/leagues/1...  Belgium           BE
# 4  https://media.api-sports.io/football/leagues/7...   Brazil           BR
#
#    seasons
# 0        5
# 1        3
# 2       14
# 3       14
# 4       15

# %%
import psycopg2

db_params = {
    'host': 'localhost',
    'database': 'preds',
    'user': 'postgres',
    'password': 'pass',
    'port': '5432'
}

try:
    conn = None
    cur = None 

    conn = psycopg2.connect(**db_params)
    cur = conn.cursor()

    insert_query = """
        INSERT INTO {} ({})
        VALUES ({})
    """.format('leagues', ','.join(c.columns), ','.join(['%s']*len(c.columns)))

    cur.executemany(insert_query, c.values.tolist())
    print('inserted')
    conn.commit()
except Exception as e:
    print(f'Error {e}')

finally:
    if cur is not None:
        cur.close()
    if conn is not None:
        conn.close()
# Out:
# inserted

# %% [markdown]
# # 2. Teams stats in each season

# %%
import pandas as pd

c = pd.read_csv('data/contests.csv')
s = pd.read_csv('data/seasons.csv')
es = pd.read_csv('data/european_seasons.csv')

# %%
c.head()
# Out:
#    league_id                name    type  \
# 0          4   Euro Championship     Cup
# 1         21  Confederations Cup     Cup
# 2         61             Ligue 1  League
# 3        144  Jupiler Pro League  League
# 4         71             Serie A  League
#
#                                                 logo  country country_code  \
# 0  https://media.api-sports.io/football/leagues/4...    World          NaN
# 1  https://media.api-sports.io/football/leagues/2...    World          NaN
# 2  https://media.api-sports.io/football/leagues/6...   France           FR
# 3  https://media.api-sports.io/football/leagues/1...  Belgium           BE
# 4  https://media.api-sports.io/football/leagues/7...   Brazil           BR
#
#    seasons
# 0        5
# 1        3
# 2       14
# 3       14
# 4       15

# %%
valid_s = set(zip(s[s['statistics_fixtures'] == True]['league_id'], 
                  s[s['statistics_fixtures'] == True]['year']))

# %%
valid_s
# Out:
# {(1, 2018),
#  (1, 2022),
#  (2, 2015),
#  (2, 2016),
#  (2, 2017),
#  (2, 2018),
#  (2, 2019),
#  (2, 2020),
#  (2, 2021),
#  (2, 2022),
#  (2, 2023),
#  (3, 2015),
#  (3, 2016),
#  (3, 2017),
#  (3, 2018),
#  (3, 2019),
#  (3, 2020),
#  (3, 2021),
#  (3, 2022),
#  (3, 2023),
#  (4, 2016),
#  (4, 2020),
#  (5, 2018),
#  (5, 2020),
#  (5, 2022),
#  (6, 2019),
#  (6, 2021),
#  (6, 2023),
#  (7, 2019),
#  (7, 2023),
#  (8, 2023),
#  (9, 2015),
#  (9, 2016),
#  (9, 2019),
#  (9, 2021),
#  (10, 2018),
#  (10, 2019),
#  (10, 2021),
#  (10, 2022),
#  (10, 2023),
#  (10, 2024),
#  (11, 2019),
#  (11, 2020),
#  (11, 2021),
#  (283, 2019),
#  (283, 2020),
#  (283, 2021),
#  (283, 2022),
#  (283, 2023),
#  (286, 2019),
#  (286, 2020),
#  (286, 2021),
#  (286, 2022),
#  (286, 2023),
#  (288, 2019),
#  (288, 2020),
#  (288, 2021),
#  (288, 2022),
#  (288, 2023),
#  (292, 2020),
#  (292, 2021),
#  (292, 2022),
#  (292, 2023),
#  (293, 2020),
#  (296, 2023),
#  (301, 2018),
#  (301, 2021),
#  (301, 2022),
#  (301, 2023),
#  (305, 2023),
#  (307, 2016),
#  (307, 2017),
#  (307, 2018),
#  (307, 2019),
#  (307, 2020),
#  (307, 2021),
#  (307, 2022),
#  (307, 2023),
#  (318, 2018),
#  (318, 2019),
#  (318, 2020),
#  (318, 2021),
#  (318, 2022),
#  (318, 2023),
#  (323, 2018),
#  (323, 2019),
#  (323, 2020),
#  (323, 2021),
#  (323, 2022),
#  (323, 2023),
#  (332, 2019),
#  (332, 2020),
#  (332, 2021),
#  (332, 2022),
#  (332, 2023),
#  (333, 2016),
#  (333, 2017),
#  (333, 2018),
#  (333, 2019),
#  (333, 2020),
#  (333, 2021),
#  (333, 2022),
#  (333, 2023),
#  (344, 2023),
#  (344, 2024),
#  (345, 2019),
#  (345, 2020),
#  (345, 2021),
#  (345, 2022),
#  (345, 2023),
#  (357, 2023),
#  (357, 2024),
#  (373, 2019),
#  (373, 2020),
#  (373, 2021),
#  (373, 2022),
#  (373, 2023),
#  (383, 2021),
#  (383, 2022),
#  (383, 2023),
#  (389, 2022),
#  (389, 2023),
#  (475, 2020),
#  (475, 2021),
#  (475, 2022),
#  (475, 2023),
#  (475, 2024),
#  (479, 2020),
#  (479, 2023),
#  (479, 2024),
#  (480, 2020),
#  (490, 2023),
#  (493, 2023),
#  (504, 2023),
#  (504, 2024),
#  (525, 2022),
#  (525, 2023),
#  (526, 2020),
#  (526, 2021),
#  (526, 2022),
#  (526, 2023),
#  (528, 2015),
#  (528, 2017),
#  (528, 2018),
#  (528, 2019),
#  (528, 2020),
#  (528, 2021),
#  (528, 2022),
#  (528, 2023),
#  (529, 2015),
#  (529, 2016),
#  (529, 2017),
#  (529, 2018),
#  (529, 2019),
#  (529, 2020),
#  (529, 2021),
#  (529, 2022),
#  (529, 2023),
#  (531, 2016),
#  (531, 2017),
#  (531, 2018),
#  (531, 2019),
#  (531, 2020),
#  (531, 2021),
#  (531, 2022),
#  (531, 2023),
#  (533, 2020),
#  (533, 2021),
#  (533, 2022),
#  (533, 2023),
#  (536, 2022),
#  (536, 2023),
#  (543, 2019),
#  (543, 2020),
#  (543, 2021),
#  (543, 2022),
#  (547, 2016),
#  (547, 2018),
#  (547, 2019),
#  (547, 2020),
#  (547, 2021),
#  (547, 2022),
#  (547, 2023),
#  (551, 2020),
#  (551, 2021),
#  (551, 2022),
#  (551, 2023),
#  (556, 2016),
#  (556, 2017),
#  (556, 2018),
#  (556, 2019),
#  (556, 2020),
#  (556, 2021),
#  (556, 2022),
#  (556, 2023),
#  (667, 2023),
#  (667, 2024),
#  (714, 2022),
#  (768, 2023),
#  (772, 2023),
#  (848, 2021),
#  (848, 2022),
#  (848, 2023),
#  (960, 2023),
#  (1032, 2023),
#  (1032, 2024)}

# %%
s[s['current']==True].head()
# Out:
#     Unnamed: 0  league_id  year       start         end  current  events  \
# 4            4          4  2024  2024-06-14  2024-06-26     True   False
# 7            7         21  2017  2017-06-17  2017-07-02     True    True
# 21          21         61  2023  2023-08-11  2024-05-18     True    True
# 35          35        144  2023  2023-07-28  2024-05-26     True    True
# 50          50         71  2024  2024-04-13  2024-12-08     True    True
#
#     lineups  statistics_fixtures  statistics_players  standings  players  \
# 4     False                False               False       True    False
# 7      True                 True               False      False     True
# 21     True                 True                True       True     True
# 35     True                 True                True       True     True
# 50     True                 True                True       True     True
#
#     top_scorers  top_assists  top_cards  injuries  predictions   odds
# 4         False        False      False     False         True  False
# 7          True         True       True     False         True  False
# 21         True         True       True      True         True   True
# 35         True         True       True     False         True   True
# 50         True         True       True     False         True   True

# %%
me = es[es['current']==True]

# %%
mee = me.merge(s,on=['league_id','year'])

# %%
from datetime import date
t = date.today()
t
# Out:
# datetime.date(2024, 6, 9)

# %%
mee['end'] = pd.to_datetime(mee['end']).dt.date
mee[(mee['end'] > t)&(mee['statistics_fixtures_x']==True)]
# Out:
#      Unnamed: 0_x  league_id                       name  country  year  \
# 77            423        142  Primera División Femenina    Spain  2023
# 284          1624        103                Eliteserien   Norway  2024
# 385          2228        113                Allsvenskan   Sweden  2024
# 386          2237        114                 Superettan   Sweden  2024
# 475          2722        357           Premier Division  Ireland  2024
# 519          3065        116             Premier League  Belarus  2024
#
#      players_x  statistics_fixtures_x  current_x  predictions_x  odds_x  ...  \
# 77        True                   True       True           True    True  ...
# 284       True                   True       True           True    True  ...
# 385       True                   True       True           True    True  ...
# 386       True                   True       True           True    True  ...
# 475       True                   True       True           True    True  ...
# 519       True                   True       True           True    True  ...
#
#      statistics_fixtures_y statistics_players standings  players_y  \
# 77                    True               True      True       True
# 284                   True               True      True       True
# 385                   True               True      True       True
# 386                   True               True      True       True
# 475                   True               True      True       True
# 519                   True              False      True       True
#
#      top_scorers  top_assists  top_cards  injuries  predictions_y  odds_y
# 77          True         True       True     False           True    True
# 284         True         True       True      True           True    True
# 385         True         True       True      True           True    True
# 386         True         True       True     False           True    True
# 475         True         True       True     False           True    True
# 519         True         True       True     False           True    True
#
# [6 rows x 26 columns]

# %% [markdown]
# # Some operations

# %%
me = es.merge(c[['league_id', 'type', 'country']], on = 'league_id')

# %%
lis = es['league_id'].unique()

# %%
ligi = list(c[(c['type']=='League')&(c['league_id'].isin(list(lis)))&(c['seasons']>1)]['league_id'].unique())

# %%
s[(s['odds'])&(s['league_id'].isin(ligi))].drop_duplicates(subset=['league_id'])
# Out:
#       Unnamed: 0  league_id  year       start         end  current  events  \
# 21            21         61  2023  2023-08-11  2024-05-18     True    True
# 35            35        144  2023  2023-07-28  2024-05-26     True    True
# 64            64         39  2023  2023-08-11  2024-05-19     True    True
# 78            78         78  2023  2023-08-18  2024-05-27     True    True
# 92            92        135  2023  2023-08-19  2024-05-26     True    True
# ...          ...        ...   ...         ...         ...      ...     ...
# 5985        5985       1009  2023  2024-05-22  2024-05-25     True   False
# 5988        5988       1011  2023  2024-05-11  2024-05-26     True   False
# 6033        6033        915  2024  2024-03-16  2024-09-07     True    True
# 6071        6071        938  2023  2023-07-21  2024-05-18     True    True
# 6073        6073        939  2023  2023-07-21  2024-05-18     True    True
#
#       lineups  statistics_fixtures  statistics_players  standings  players  \
# 21       True                 True                True       True     True
# 35       True                 True                True       True     True
# 64       True                 True                True       True     True
# 78       True                 True                True       True     True
# 92       True                 True                True       True     True
# ...       ...                  ...                 ...        ...      ...
# 5985    False                False               False      False     True
# 5988    False                False               False      False     True
# 6033    False                False               False       True    False
# 6071    False                False               False       True     True
# 6073    False                False               False       True     True
#
#       top_scorers  top_assists  top_cards  injuries  predictions  odds
# 21           True         True       True      True         True  True
# 35           True         True       True     False         True  True
# 64           True         True       True      True         True  True
# 78           True         True       True      True         True  True
# 92           True         True       True      True         True  True
# ...           ...          ...        ...       ...          ...   ...
# 5985         True         True       True     False         True  True
# 5988         True         True       True     False         True  True
# 6033        False        False      False     False         True  True
# 6071         True         True       True     False         True  True
# 6073         True         True       True     False         True  True
#
# [177 rows x 18 columns]

# %%
c[c['type']=='League']
# Out:
#       league_id                name    type  \
# 2            61             Ligue 1  League
# 3           144  Jupiler Pro League  League
# 4            71             Serie A  League
# 5            39      Premier League  League
# 6            78          Bundesliga  League
# ...         ...                 ...     ...
# 1101       1103   Premiership Women  League
# 1102       1104              Liga 3  League
# 1104       1106           Carioca C  League
# 1105       1107         Mineiro U20  League
# 1106       1108       Sergipano U20  League
#
#                                                    logo           country  \
# 2     https://media.api-sports.io/football/leagues/6...            France
# 3     https://media.api-sports.io/football/leagues/1...           Belgium
# 4     https://media.api-sports.io/football/leagues/7...            Brazil
# 5     https://media.api-sports.io/football/leagues/3...           England
# 6     https://media.api-sports.io/football/leagues/7...           Germany
# ...                                                 ...               ...
# 1101  https://media.api-sports.io/football/leagues/1...  Northern-Ireland
# 1102  https://media.api-sports.io/football/leagues/1...           Georgia
# 1104  https://media.api-sports.io/football/leagues/1...            Brazil
# 1105  https://media.api-sports.io/football/leagues/1...            Brazil
# 1106  https://media.api-sports.io/football/leagues/1...            Brazil
#
#      country_code  seasons
# 2              FR       14
# 3              BE       14
# 4              BR       15
# 5              GB       14
# 6              DE       14
# ...           ...      ...
# 1101           GB        1
# 1102           GE        1
# 1104           BR        1
# 1105           BR        1
# 1106           BR        1
#
# [729 rows x 7 columns]
