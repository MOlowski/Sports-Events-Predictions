# %%
def get_predicted_matches(start_date, end_date):
    
    conn = None
    db_params = {
        'host': 'localhost',
        'database': 'preds',
        'user': 'postgres',
        'password': 'pass',
        'port': '5432'
    }
    #get next friday and monday dates as start and end for query

    # get upocoming matches playing from next friday to monday
    try:
        conn = psycopg2.connect(**db_params)

        query = '''
    SELECT p.*, f.league_id, fixture_date
    FROM predictions p
    JOIN fixtures f ON p.fixture_id = f.fixture_id
    WHERE f.fixture_date >= '{}' and fixture_date <= '{}'
    '''.format('2024-06-26', end_date)
        current_matches = pd.read_sql_query(query, conn)
        
        return current_matches
    except Exception as e:
        print(f'Error {e}')
        return None, None
    finally:
        if conn is not None:
            conn.close()

# %%
def get_data(endpoint, params):
    
    URL = "https://v3.football.api-sports.io/"
    headers = {
	'x-rapidapi-host': "v3.football.api-sports.io",
    'x-rapidapi-key': "fb2140228973d644db847895c454c22b"
    }
    
    response = requests.get(
        URL+endpoint,
        headers = headers,
        params = params
    )
    if response.status_code == 200:
            
        remaining = response.headers.get("x-ratelimit-requests-remaining")
        data = response.json()
        print(f"requests before reaching limit {remaining}")

    else:
        print(f"Error {response.status_code}, {response.text}")

    return data, remaining

# %%
def encode_data(data_dict, parent_key = '', sep= '_'):
    encoded = []
    for key, val in data_dict.items():
        new_key = f'{parent_key}{sep}{key}' if parent_key else key
        if isinstance(val, dict):
            encoded.extend(encode_data(val, new_key, sep=sep).items())
        elif isinstance(val, list):
            if val:
                if all(isinstance(i, dict) for i in val):
                    for k, v in enumerate(val):
                        v_key = f'{new_key}{sep}{k}'
                        encoded.extend(encode_data(v, v_key, sep=sep).items())
                else:
                    encoded.append((new_key, val))
            else:
                encoded.append((new_key, []))
        else:
            encoded.append((new_key, val))
    return dict(encoded)

# %%
def data_to_sql(table_name, df, db_params, conflict_columns):
    conn = None
    cur = None
    try:
        # Establish the connection
        conn = psycopg2.connect(**db_params)
        cur = conn.cursor()
        
        #insert data into tables
        if len(conflict_columns) == 0:
            insert_query = """
                INSERT INTO {} ({})
                VALUES ({})
            """.format(table_name, ','.join(df.columns), ','.join(['%s']*len(df.columns)))
        else:
            insert_query = """
                INSERT INTO {} ({})
                VALUES ({})
                ON CONFLICT ({}) DO NOTHING
            """.format(table_name, ','.join(df.columns), ','.join(['%s']*len(df.columns)), ','.join(conflict_columns))
        if len(df) > 0:
            last_row = df.iloc[-1]
        cur.executemany(insert_query, df.values.tolist())
        print(f'table {table_name} updated')
        
        # Commit the changes
        conn.commit()
        
    
    except Exception as e:
        print(f"Error: {e}")
        if last_row is not None:
            print(f"Last row loaded before the error occurred: {last_row}")
    finally:
        if conn is not None:
            # Close the cursor and connection
            cur.close()
        if cur is not None:
            conn.close()

# %%
def preprocess_data(odd_data):
    
    all_filtered_data = []
    for index, data in enumerate(odd_data):
        books = [len(book['bets']) for book in odd_data[index]['bookmakers']]
        bb = books.index(max(books))
        data = encode_data(data)
        filtered_data = {}
        filtered_data['fixture_id'] = data['fixture_id']
        
        for key, value in data.items():
            if value == 'Match Winner':
                match = re.search(fr'bookmakers_{bb}_bets_(\d+)_name', key)
                if match:
                    bet_number = match.group(1)
                    filtered_data['result_home'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_0_odd']
                    filtered_data['result_draw'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_1_odd']
                    filtered_data['result_away'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_2_odd']
            if value == 'Both Teams Score':
                match = re.search(fr'bookmakers_{bb}_bets_(\d+)_name', key)
                if match:
                    bet_number = match.group(1)
                    filtered_data['both_scores_true'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_0_odd']
                    filtered_data['both_scores_false'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_1_odd']
            if value == 'Double Chance':
                match = re.search(fr'bookmakers_{bb}_bets_(\d+)_name', key)
                if match:
                    bet_number = match.group(1)
                    filtered_data['double_chance_home'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_0_odd']
                    filtered_data['double_chance_away'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_1_odd']
            if value == 'First Half Winner':
                match = re.search(fr'bookmakers_{bb}_bets_(\d+)_name', key)
                if match:
                    bet_number = match.group(1)
                    filtered_data['fh_result_home'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_0_odd']
                    filtered_data['fh_result_draw'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_1_odd']
                    filtered_data['fh_result_away'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_2_odd']
            if value == 'Total - Home':
                match = re.search(fr'bookmakers_{bb}_bets_(\d+)_name', key)
                if match:
                    bet_number = match.group(1)
                    filtered_data['home_over_1'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_0_odd']
                    filtered_data['home_over_2'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_2_odd']
            if value == 'Total - Away':
                match = re.search(fr'bookmakers_{bb}_bets_(\d+)_name', key)
                if match:
                    bet_number = match.group(1)
                    filtered_data['away_over_1'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_0_odd']
                    filtered_data['away_over_2'] = data[f'bookmakers_{bb}_bets_{bet_number}_values_2_odd']
                    
            cols = ['result_home', 'result_draw', 
                    'result_away', 'both_scores_true', 
                    'both_scores_false', 'double_chance_home', 
                    'double_chance_away', 'fh_result_home', 
                    'fh_result_draw', 'fh_result_away', 
                    'home_over_1', 'home_over_2', 
                    'away_over_1', 'away_over_2']
        for col in cols:
            if col not in filtered_data:
                filtered_data[col] = 0
        all_filtered_data.append(filtered_data)
    df = pd.DataFrame(all_filtered_data)
    return df

# %%
import requests
import re
import datetime
from datetime import date
import pandas as pd
import psycopg2

t = date.today()
start_date = t+datetime.timedelta(1) if t.weekday() == 4 else t
end_date = t+datetime.timedelta(1) if t.weekday() == 0 else t
while start_date.weekday() != 4:
    start_date += datetime.timedelta(1)
while end_date.weekday() != 0:
    end_date += datetime.timedelta(1)

matches = get_predicted_matches(start_date, end_date)

#get only matches with odds available
c = pd.read_csv('data/european_seasons.csv')
matches = matches.merge(c[['league_id','odds']], on='league_id')
matches = matches[matches['odds']]
matches_list = list(matches['fixture_id'].unique())
leagues_list = list(matches['league_id'].unique())
    
odds_data = []
remaining = 10000
done = False
date = start_date
page = 1

while remaining > 0 and not done:
    season = list(c[c['league_id']==leagues_list[0]]['year'])[-1]
    params = {'league':leagues_list[0],
              'date':date,
              'season':season,
              'page':page}
    response, remaining = get_data('odds', params)    
    date+=datetime.timedelta(1)
    if page != response['paging']['total']:
        page += 1
    else:
        page = 1
        leagues_list.pop(0)
        
    if len(response['response'])>0:
        odds_data.extend(match for match in response['response'])
    
    remaining = int(remaining)
    done = True if len(leagues_list)==0 else False
    
print(done)
if len(odds_data) > 0:
    # preprocess data
    df = preprocess_data(odds_data)
    # send to db
    #data_to_sql('odds', df, params, 'fixture_id')
# Out:
# C:\Users\olows\AppData\Local\Temp\ipykernel_10912\2420774886.py:23: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   current_matches = pd.read_sql_query(query, conn)
# requests before reaching limit 498
# requests before reaching limit 497
# requests before reaching limit 496
# requests before reaching limit 495
# requests before reaching limit 494
# requests before reaching limit 493
# requests before reaching limit 492
# requests before reaching limit 491
# requests before reaching limit 490
# requests before reaching limit 489
# requests before reaching limit 488
# requests before reaching limit 487
# requests before reaching limit 486
# requests before reaching limit 485
# requests before reaching limit 484
# requests before reaching limit 483
# requests before reaching limit 482
# requests before reaching limit 481
# True

# %%
response
# Out:
# {'get': 'odds',
#  'parameters': {'league': '362',
#   'date': '2024-07-22',
#   'season': '2024',
#   'page': '1'},
#  'errors': [],
#  'results': 0,
#  'paging': {'current': 1, 'total': 1},
#  'response': []}

# %%
a, b = get_data('odds', {'fixture': 1132615})
# Out:
# requests before reaching limit 497

# %%
c = encode_data(a['response'][0])

# %%
for b in a['response'][0]['bookmakers']:
    print(len(b['bets']))
# Out:
# 2
# 25
# 23
# 15
# 3

# %% [markdown]
# ### Preprocces

# %%
a
# Out:
# {'get': 'odds',
#  'parameters': {'fixture': '1132615'},
#  'errors': [],
#  'results': 1,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'league': {'id': 233,
#     'name': 'Premier League',
#     'country': 'Egypt',
#     'logo': 'https://media.api-sports.io/football/leagues/233.png',
#     'flag': 'https://media.api-sports.io/flags/eg.svg',
#     'season': 2023},
#    'fixture': {'id': 1132615,
#     'timezone': 'UTC',
#     'date': '2024-07-01T17:00:00+00:00',
#     'timestamp': 1719853200},
#    'update': '2024-07-01T15:00:18+00:00',
#    'bookmakers': [{'id': 27,
#      'name': 'NordicBet',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '7.50'},
#         {'value': 'Draw', 'odd': '4.50'},
#         {'value': 'Away', 'odd': '1.38'}]},
#       {'id': 2,
#        'name': 'Home/Away',
#        'values': [{'value': 'Home', 'odd': '6.00'},
#         {'value': 'Away', 'odd': '1.11'}]},
#       {'id': 3,
#        'name': 'Second Half Winner',
#        'values': [{'value': 'Home', 'odd': '6.50'},
#         {'value': 'Draw', 'odd': '2.65'},
#         {'value': 'Away', 'odd': '1.70'}]},
#       {'id': 5,
#        'name': 'Goals Over/Under',
#        'values': [{'value': 'Over 3.5', 'odd': '3.50'},
#         {'value': 'Under 3.5', 'odd': '1.28'},
#         {'value': 'Over 1.5', 'odd': '1.30'},
#         {'value': 'Under 1.5', 'odd': '3.30'},
#         {'value': 'Over 2.5', 'odd': '1.95'},
#         {'value': 'Under 2.5', 'odd': '1.80'}]},
#       {'id': 6,
#        'name': 'Goals Over/Under First Half',
#        'values': [{'value': 'Over 0.5', 'odd': '1.39'},
#         {'value': 'Under 0.5', 'odd': '2.80'}]},
#       {'id': 26,
#        'name': 'Goals Over/Under - Second Half',
#        'values': [{'value': 'Over 1.5', 'odd': '2.14'},
#         {'value': 'Under 1.5', 'odd': '1.64'}]},
#       {'id': 7,
#        'name': 'HT/FT Double',
#        'values': [{'value': 'Home/Draw', 'odd': '23.00'},
#         {'value': 'Home/Away', 'odd': '26.00'},
#         {'value': 'Draw/Away', 'odd': '3.75'},
#         {'value': 'Draw/Draw', 'odd': '6.00'},
#         {'value': 'Home/Home', 'odd': '15.00'},
#         {'value': 'Draw/Home', 'odd': '15.00'},
#         {'value': 'Away/Home', 'odd': '51.00'},
#         {'value': 'Away/Draw', 'odd': '21.00'},
#         {'value': 'Away/Away', 'odd': '2.10'}]},
#       {'id': 8,
#        'name': 'Both Teams Score',
#        'values': [{'value': 'Yes', 'odd': '2.25'},
#         {'value': 'No', 'odd': '1.60'}]},
#       {'id': 10,
#        'name': 'Exact Score',
#        'values': [{'value': '1:0', 'odd': '15.00'},
#         {'value': '2:0', 'odd': '46.00'},
#         {'value': '2:1', 'odd': '23.00'},
#         {'value': '3:0', 'odd': '51.00'},
#         {'value': '3:1', 'odd': '51.00'},
#         {'value': '3:2', 'odd': '51.00'},
#         {'value': '4:0', 'odd': '51.00'},
#         {'value': '4:1', 'odd': '51.00'},
#         {'value': '4:2', 'odd': '51.00'},
#         {'value': '5:0', 'odd': '51.00'},
#         {'value': '5:1', 'odd': '51.00'},
#         {'value': '6:0', 'odd': '51.00'},
#         {'value': '0:0', 'odd': '9.50'},
#         {'value': '1:1', 'odd': '7.50'},
#         {'value': '2:2', 'odd': '21.00'},
#         {'value': '3:3', 'odd': '51.00'},
#         {'value': '0:1', 'odd': '5.00'},
#         {'value': '0:2', 'odd': '5.00'},
#         {'value': '0:3', 'odd': '7.50'},
#         {'value': '0:4', 'odd': '17.00'},
#         {'value': '0:5', 'odd': '36.00'},
#         {'value': '0:6', 'odd': '51.00'},
#         {'value': '1:2', 'odd': '7.00'},
#         {'value': '1:3', 'odd': '11.00'},
#         {'value': '1:4', 'odd': '23.00'},
#         {'value': '1:5', 'odd': '51.00'},
#         {'value': '2:3', 'odd': '29.00'},
#         {'value': '2:4', 'odd': '51.00'}]},
#       {'id': 11,
#        'name': 'Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '3.40'},
#         {'value': '1st Half', 'odd': '3.00'},
#         {'value': '2nd Half', 'odd': '2.05'}]},
#       {'id': 31,
#        'name': 'Correct Score - First Half',
#        'values': [{'value': '1:0', 'odd': '7.50'},
#         {'value': '2:0', 'odd': '46.00'},
#         {'value': '2:1', 'odd': '46.00'},
#         {'value': '3:0', 'odd': '51.00'},
#         {'value': '3:1', 'odd': '51.00'},
#         {'value': '3:2', 'odd': '51.00'},
#         {'value': '4:0', 'odd': '51.00'},
#         {'value': '4:1', 'odd': '51.00'},
#         {'value': '4:2', 'odd': '51.00'},
#         {'value': '4:3', 'odd': '51.00'},
#         {'value': '5:0', 'odd': '51.00'},
#         {'value': '5:1', 'odd': '51.00'},
#         {'value': '5:2', 'odd': '51.00'},
#         {'value': '5:3', 'odd': '51.00'},
#         {'value': '5:4', 'odd': '51.00'},
#         {'value': '0:0', 'odd': '2.80'},
#         {'value': '1:1', 'odd': '8.50'},
#         {'value': '2:2', 'odd': '51.00'},
#         {'value': '3:3', 'odd': '51.00'},
#         {'value': '4:4', 'odd': '51.00'},
#         {'value': '0:1', 'odd': '3.00'},
#         {'value': '0:2', 'odd': '6.00'},
#         {'value': '0:3', 'odd': '19.00'},
#         {'value': '0:4', 'odd': '51.00'},
#         {'value': '0:5', 'odd': '51.00'},
#         {'value': '1:2', 'odd': '17.00'},
#         {'value': '1:3', 'odd': '51.00'},
#         {'value': '1:4', 'odd': '51.00'},
#         {'value': '1:5', 'odd': '51.00'},
#         {'value': '2:3', 'odd': '51.00'},
#         {'value': '2:4', 'odd': '51.00'},
#         {'value': '2:5', 'odd': '51.00'},
#         {'value': '3:4', 'odd': '51.00'},
#         {'value': '3:5', 'odd': '51.00'},
#         {'value': '4:5', 'odd': '51.00'},
#         {'value': '5:5', 'odd': '51.00'}]},
#       {'id': 12,
#        'name': 'Double Chance',
#        'values': [{'value': 'Home/Draw', 'odd': '2.90'},
#         {'value': 'Home/Away', 'odd': '1.15'},
#         {'value': 'Draw/Away', 'odd': '1.04'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '6.50'},
#         {'value': 'Draw', 'odd': '2.25'},
#         {'value': 'Away', 'odd': '1.90'}]},
#       {'id': 16,
#        'name': 'Total - Home',
#        'values': [{'value': 'Over 0.5', 'odd': '1.95'},
#         {'value': 'Under 0.5', 'odd': '1.80'}]},
#       {'id': 17,
#        'name': 'Total - Away',
#        'values': [{'value': 'Over 1.5', 'odd': '1.60'},
#         {'value': 'Under 1.5', 'odd': '2.25'}]},
#       {'id': 21,
#        'name': 'Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '1.87'},
#         {'value': 'Even', 'odd': '1.87'}]},
#       {'id': 43,
#        'name': 'Home Team Score a Goal',
#        'values': [{'value': 'Yes', 'odd': '1.95'},
#         {'value': 'No', 'odd': '1.80'}]},
#       {'id': 44,
#        'name': 'Away Team Score a Goal',
#        'values': [{'value': 'Yes', 'odd': '1.11'},
#         {'value': 'No', 'odd': '6.00'}]},
#       {'id': 184,
#        'name': 'To Score in Both Halves',
#        'values': [{'value': 'Yes', 'odd': '1.80'},
#         {'value': 'No', 'odd': '1.95'}]}]},
#     {'id': 1,
#      'name': '10Bet',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '8.50'},
#         {'value': 'Draw', 'odd': '4.33'},
#         {'value': 'Away', 'odd': '1.35'}]},
#       {'id': 2,
#        'name': 'Home/Away',
#        'values': [{'value': 'Home', 'odd': '6.25'},
#         {'value': 'Away', 'odd': '1.09'}]},
#       {'id': 4,
#        'name': 'Asian Handicap',
#        'values': [{'value': 'Home +1', 'odd': '2.35'},
#         {'value': 'Away +1', 'odd': '1.57'},
#         {'value': 'Home +1.5', 'odd': '1.80'},
#         {'value': 'Away +1.5', 'odd': '2.00'}]},
#       {'id': 5,
#        'name': 'Goals Over/Under',
#        'values': [{'value': 'Over 3.5', 'odd': '3.35'},
#         {'value': 'Under 3.5', 'odd': '1.30'},
#         {'value': 'Over 1.5', 'odd': '1.28'},
#         {'value': 'Under 1.5', 'odd': '3.40'},
#         {'value': 'Over 2.5', 'odd': '1.91'},
#         {'value': 'Under 2.5', 'odd': '1.83'},
#         {'value': 'Over 0.5', 'odd': '1.05'},
#         {'value': 'Under 0.5', 'odd': '8.50'}]},
#       {'id': 6,
#        'name': 'Goals Over/Under First Half',
#        'values': [{'value': 'Over 1.5', 'odd': '2.80'},
#         {'value': 'Under 1.5', 'odd': '1.38'},
#         {'value': 'Over 0.5', 'odd': '1.38'},
#         {'value': 'Under 0.5', 'odd': '2.80'}]},
#       {'id': 26,
#        'name': 'Goals Over/Under - Second Half',
#        'values': [{'value': 'Over 1.5', 'odd': '2.10'},
#         {'value': 'Under 1.5', 'odd': '1.67'},
#         {'value': 'Over 0.5', 'odd': '1.22'},
#         {'value': 'Under 0.5', 'odd': '3.80'}]},
#       {'id': 7,
#        'name': 'HT/FT Double',
#        'values': [{'value': 'Home/Draw', 'odd': '21.00'},
#         {'value': 'Home/Away', 'odd': '23.00'},
#         {'value': 'Draw/Away', 'odd': '3.80'},
#         {'value': 'Draw/Draw', 'odd': '6.25'},
#         {'value': 'Home/Home', 'odd': '13.00'},
#         {'value': 'Draw/Home', 'odd': '15.00'},
#         {'value': 'Away/Home', 'odd': '56.00'},
#         {'value': 'Away/Draw', 'odd': '19.00'},
#         {'value': 'Away/Away', 'odd': '1.95'}]},
#       {'id': 8,
#        'name': 'Both Teams Score',
#        'values': [{'value': 'Yes', 'odd': '2.20'},
#         {'value': 'No', 'odd': '1.55'}]},
#       {'id': 9,
#        'name': 'Handicap Result',
#        'values': [{'value': 'Home +1', 'odd': '3.00'},
#         {'value': 'Away +1', 'odd': '2.05'},
#         {'value': 'Draw +1', 'odd': '3.35'},
#         {'value': 'Home +2', 'odd': '1.67'},
#         {'value': 'Draw +2', 'odd': '3.85'},
#         {'value': 'Away +2', 'odd': '3.80'}]},
#       {'id': 10,
#        'name': 'Exact Score',
#        'values': [{'value': '1:0', 'odd': '13.00'},
#         {'value': '2:0', 'odd': '41.00'},
#         {'value': '2:1', 'odd': '21.00'},
#         {'value': '3:0', 'odd': '101.00'},
#         {'value': '3:1', 'odd': '67.00'},
#         {'value': '3:2', 'odd': '67.00'},
#         {'value': '0:0', 'odd': '8.50'},
#         {'value': '1:1', 'odd': '7.50'},
#         {'value': '2:2', 'odd': '21.00'},
#         {'value': '3:3', 'odd': '91.00'},
#         {'value': '0:1', 'odd': '4.75'},
#         {'value': '0:2', 'odd': '4.75'},
#         {'value': '0:3', 'odd': '7.00'},
#         {'value': '0:4', 'odd': '13.00'},
#         {'value': '0:5', 'odd': '29.00'},
#         {'value': '0:6', 'odd': '67.00'},
#         {'value': '1:2', 'odd': '7.00'},
#         {'value': '1:3', 'odd': '10.00'},
#         {'value': '1:4', 'odd': '19.00'},
#         {'value': '1:5', 'odd': '41.00'},
#         {'value': '1:6', 'odd': '81.00'},
#         {'value': '2:3', 'odd': '29.00'},
#         {'value': '2:4', 'odd': '46.00'},
#         {'value': '2:5', 'odd': '91.00'},
#         {'value': '3:4', 'odd': '126.00'}]},
#       {'id': 11,
#        'name': 'Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '3.40'},
#         {'value': '1st Half', 'odd': '3.00'},
#         {'value': '2nd Half', 'odd': '2.05'}]},
#       {'id': 31,
#        'name': 'Correct Score - First Half',
#        'values': [{'value': '1:0', 'odd': '7.00'},
#         {'value': '2:0', 'odd': '34.00'},
#         {'value': '2:1', 'odd': '41.00'},
#         {'value': '0:0', 'odd': '2.80'},
#         {'value': '1:1', 'odd': '7.50'},
#         {'value': '2:2', 'odd': '61.00'},
#         {'value': '0:1', 'odd': '2.55'},
#         {'value': '0:2', 'odd': '5.00'},
#         {'value': '0:3', 'odd': '13.00'},
#         {'value': '0:4', 'odd': '41.00'},
#         {'value': '1:2', 'odd': '13.00'},
#         {'value': '1:3', 'odd': '34.00'},
#         {'value': '1:4', 'odd': '91.00'}]},
#       {'id': 12,
#        'name': 'Double Chance',
#        'values': [{'value': 'Home/Draw', 'odd': '3.00'},
#         {'value': 'Home/Away', 'odd': '1.14'},
#         {'value': 'Draw/Away', 'odd': '1.03'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.00'},
#         {'value': 'Draw', 'odd': '2.30'},
#         {'value': 'Away', 'odd': '1.85'}]},
#       {'id': 14,
#        'name': 'Team To Score First',
#        'values': [{'value': 'Home', 'odd': '4.00'},
#         {'value': 'Draw', 'odd': '8.50'},
#         {'value': 'Away', 'odd': '1.35'}]},
#       {'id': 15,
#        'name': 'Team To Score Last',
#        'values': [{'value': 'Home', 'odd': '4.00'},
#         {'value': 'Draw', 'odd': '8.50'},
#         {'value': 'Away', 'odd': '1.35'}]},
#       {'id': 32,
#        'name': 'Win Both Halves',
#        'values': [{'value': 'Home', 'odd': '46.00'},
#         {'value': 'Away', 'odd': '3.10'}]},
#       {'id': 16,
#        'name': 'Total - Home',
#        'values': [{'value': 'Over 1.5', 'odd': '6.25'},
#         {'value': 'Under 1.5', 'odd': '1.09'},
#         {'value': 'Over 0.5', 'odd': '2.00'},
#         {'value': 'Under 0.5', 'odd': '1.73'}]},
#       {'id': 17,
#        'name': 'Total - Away',
#        'values': [{'value': 'Over 1.5', 'odd': '1.57'},
#         {'value': 'Under 1.5', 'odd': '2.25'},
#         {'value': 'Over 2.5', 'odd': '2.75'},
#         {'value': 'Under 2.5', 'odd': '1.40'},
#         {'value': 'Over 0.5', 'odd': '1.10'},
#         {'value': 'Under 0.5', 'odd': '5.75'}]},
#       {'id': 18,
#        'name': 'Handicap Result - First Half',
#        'values': [{'value': 'Home -1', 'odd': '26.00'},
#         {'value': 'Away -1', 'odd': '1.10'},
#         {'value': 'Draw -1', 'odd': '6.25'},
#         {'value': 'Home +1', 'odd': '1.85'},
#         {'value': 'Away +1', 'odd': '4.50'},
#         {'value': 'Draw +1', 'odd': '2.80'},
#         {'value': 'Home +2', 'odd': '1.17'},
#         {'value': 'Draw +2', 'odd': '5.75'},
#         {'value': 'Away +2', 'odd': '11.00'}]},
#       {'id': 19,
#        'name': 'Asian Handicap First Half',
#        'values': [{'value': 'Home +0.5', 'odd': '1.90'},
#         {'value': 'Away +0.5', 'odd': '1.85'}]},
#       {'id': 21,
#        'name': 'Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '1.85'},
#         {'value': 'Even', 'odd': '1.85'}]},
#       {'id': 39,
#        'name': 'To Win Either Half',
#        'values': [{'value': 'Home', 'odd': '4.00'},
#         {'value': 'Away', 'odd': '1.20'}]},
#       {'id': 40,
#        'name': 'Home Team Exact Goals Number',
#        'values': [{'value': 1, 'odd': '2.65'},
#         {'value': 0, 'odd': '1.73'},
#         {'value': 'more 2', 'odd': '6.25'}]},
#       {'id': 41,
#        'name': 'Away Team Exact Goals Number',
#        'values': [{'value': 1, 'odd': '3.25'},
#         {'value': 0, 'odd': '5.75'},
#         {'value': 'more 2', 'odd': '1.57'}]},
#       {'id': 24,
#        'name': 'Results/Both Teams Score',
#        'values': [{'value': 'Home/Yes', 'odd': '17.00'},
#         {'value': 'Draw/Yes', 'odd': '6.50'},
#         {'value': 'Away/Yes', 'odd': '3.55'},
#         {'value': 'Home/No', 'odd': '12.00'},
#         {'value': 'Draw/No', 'odd': '8.50'},
#         {'value': 'Away/No', 'odd': '2.00'}]},
#       {'id': 25,
#        'name': 'Result/Total Goals',
#        'values': [{'value': 'Home/Over 1.5', 'odd': '12.00'},
#         {'value': 'Away/Over 1.5', 'odd': '1.67'},
#         {'value': 'Draw/Over 1.5', 'odd': '6.50'},
#         {'value': 'Draw/Under 1.5', 'odd': '8.50'},
#         {'value': 'Home/Under 1.5', 'odd': '13.00'},
#         {'value': 'Away/Under 1.5', 'odd': '4.75'},
#         {'value': 'Home/Over 2.5', 'odd': '15.00'},
#         {'value': 'Draw/Over 2.5', 'odd': '19.00'},
#         {'value': 'Away/Over 2.5', 'odd': '2.25'},
#         {'value': 'Home/Under 2.5', 'odd': '12.00'},
#         {'value': 'Draw/Under 2.5', 'odd': '4.75'},
#         {'value': 'Away/Under 2.5', 'odd': '2.90'}]},
#       {'id': 54,
#        'name': 'First 10 min Winner',
#        'values': [{'value': 'Home', 'odd': '17.00'},
#         {'value': 'Draw', 'odd': '1.18'},
#         {'value': 'Away', 'odd': '5.75'}]},
#       {'id': 45,
#        'name': 'Corners Over Under',
#        'values': [{'value': 'Over 8.5', 'odd': '1.70'},
#         {'value': 'Under 8.5', 'odd': '2.05'}]},
#       {'id': 105,
#        'name': 'Home Team Total Goals(1st Half)',
#        'values': [{'value': 'Over 1.5', 'odd': '19.00'},
#         {'value': 'Under 1.5', 'odd': '1.01'},
#         {'value': 'Over 0.5', 'odd': '3.70'},
#         {'value': 'Under 0.5', 'odd': '1.22'}]},
#       {'id': 106,
#        'name': 'Away Team Total Goals(1st Half)',
#        'values': [{'value': 'Over 1.5', 'odd': '3.80'},
#         {'value': 'Under 1.5', 'odd': '1.22'},
#         {'value': 'Over 2.5', 'odd': '10.00'},
#         {'value': 'Under 2.5', 'odd': '1.03'},
#         {'value': 'Over 0.5', 'odd': '1.57'},
#         {'value': 'Under 0.5', 'odd': '2.25'}]},
#       {'id': 107,
#        'name': 'Home Team Total Goals(2nd Half)',
#        'values': [{'value': 'Over 1.5', 'odd': '11.00'},
#         {'value': 'Under 1.5', 'odd': '1.02'},
#         {'value': 'Over 0.5', 'odd': '2.95'},
#         {'value': 'Under 0.5', 'odd': '1.35'}]},
#       {'id': 108,
#        'name': 'Away Team Total Goals(2nd Half)',
#        'values': [{'value': 'Over 1.5', 'odd': '2.80'},
#         {'value': 'Under 1.5', 'odd': '1.38'},
#         {'value': 'Over 2.5', 'odd': '7.00'},
#         {'value': 'Under 2.5', 'odd': '1.07'},
#         {'value': 'Over 0.5', 'odd': '1.38'},
#         {'value': 'Under 0.5', 'odd': '2.80'}]},
#       {'id': 63,
#        'name': 'Odd/Even - Second Half',
#        'values': [{'value': 'Odd', 'odd': '1.95'},
#         {'value': 'Even', 'odd': '1.77'}]},
#       {'id': 109,
#        'name': 'Draw No Bet (1st Half)',
#        'values': [{'value': 'Home', 'odd': '4.75'},
#         {'value': 'Away', 'odd': '1.15'}]},
#       {'id': 85,
#        'name': 'Total Corners (3 way)',
#        'values': [{'value': 'Over 8', 'odd': '1.70'},
#         {'value': 'Under 8', 'odd': '2.62'},
#         {'value': 'Exactly 8', 'odd': '7.50'},
#         {'value': 'Over 9', 'odd': '2.05'},
#         {'value': 'Under 9', 'odd': '2.05'},
#         {'value': 'Exactly 9', 'odd': '7.50'}]},
#       {'id': 137,
#        'name': '1x2 - 60 minutes',
#        'values': [{'value': 'Home', 'odd': '7.50'},
#         {'value': 'Draw', 'odd': '3.00'},
#         {'value': 'Away', 'odd': '1.62'}]},
#       {'id': 139,
#        'name': '1x2 - 30 minutes',
#        'values': [{'value': 'Home', 'odd': '8.50'},
#         {'value': 'Draw', 'odd': '1.77'},
#         {'value': 'Away', 'odd': '2.50'}]},
#       {'id': 84,
#        'name': 'Total Corners (3 way) (1st Half)',
#        'values': [{'value': 'Over 4', 'odd': '2.00'},
#         {'value': 'Under 4', 'odd': '2.40'},
#         {'value': 'Exactly 4', 'odd': '5.00'}]},
#       {'id': 334,
#        'name': '1x2 - 70 minutes',
#        'values': [{'value': 'Home', 'odd': '7.50'},
#         {'value': 'Draw', 'odd': '3.45'},
#         {'value': 'Away', 'odd': '1.53'}]}]},
#     {'id': 7,
#      'name': 'William Hill',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '7.00'},
#         {'value': 'Draw', 'odd': '4.00'},
#         {'value': 'Away', 'odd': '1.40'}]},
#       {'id': 3,
#        'name': 'Second Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.00'},
#         {'value': 'Draw', 'odd': '2.50'},
#         {'value': 'Away', 'odd': '1.73'}]},
#       {'id': 8,
#        'name': 'Both Teams Score',
#        'values': [{'value': 'Yes', 'odd': '2.30'},
#         {'value': 'No', 'odd': '1.57'}]},
#       {'id': 29,
#        'name': 'Win to Nil - Home',
#        'values': [{'value': 'Yes', 'odd': '10.00'},
#         {'value': 'No', 'odd': '1.04'}]},
#       {'id': 30,
#        'name': 'Win to Nil - Away',
#        'values': [{'value': 'Yes', 'odd': '2.00'},
#         {'value': 'No', 'odd': '1.73'}]},
#       {'id': 10,
#        'name': 'Exact Score',
#        'values': [{'value': '1:0', 'odd': '17.00'},
#         {'value': '2:0', 'odd': '46.00'},
#         {'value': '2:1', 'odd': '29.00'},
#         {'value': '3:0', 'odd': '101.00'},
#         {'value': '3:1', 'odd': '91.00'},
#         {'value': '3:2', 'odd': '91.00'},
#         {'value': '4:0', 'odd': '151.00'},
#         {'value': '4:1', 'odd': '151.00'},
#         {'value': '4:2', 'odd': '151.00'},
#         {'value': '4:3', 'odd': '151.00'},
#         {'value': '5:0', 'odd': '201.00'},
#         {'value': '5:1', 'odd': '201.00'},
#         {'value': '5:2', 'odd': '201.00'},
#         {'value': '6:0', 'odd': '151.00'},
#         {'value': '6:1', 'odd': '151.00'},
#         {'value': '6:2', 'odd': '151.00'},
#         {'value': '0:0', 'odd': '9.50'},
#         {'value': '1:1', 'odd': '8.00'},
#         {'value': '2:2', 'odd': '23.00'},
#         {'value': '3:3', 'odd': '101.00'},
#         {'value': '4:4', 'odd': '151.00'},
#         {'value': '0:1', 'odd': '5.00'},
#         {'value': '0:2', 'odd': '5.50'},
#         {'value': '0:3', 'odd': '8.00'},
#         {'value': '0:4', 'odd': '15.00'},
#         {'value': '0:5', 'odd': '36.00'},
#         {'value': '0:6', 'odd': '81.00'},
#         {'value': '1:2', 'odd': '8.50'},
#         {'value': '1:3', 'odd': '13.00'},
#         {'value': '1:4', 'odd': '23.00'},
#         {'value': '1:5', 'odd': '51.00'},
#         {'value': '1:6', 'odd': '101.00'},
#         {'value': '2:3', 'odd': '36.00'},
#         {'value': '2:4', 'odd': '61.00'},
#         {'value': '2:5', 'odd': '101.00'},
#         {'value': '2:6', 'odd': '151.00'},
#         {'value': '3:4', 'odd': '126.00'},
#         {'value': '0:7', 'odd': '126.00'},
#         {'value': '1:7', 'odd': '151.00'},
#         {'value': '7:0', 'odd': '151.00'},
#         {'value': '7:1', 'odd': '151.00'},
#         {'value': '0:8', 'odd': '151.00'},
#         {'value': '0:9', 'odd': '151.00'},
#         {'value': '0:10', 'odd': '151.00'}]},
#       {'id': 11,
#        'name': 'Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '3.30'},
#         {'value': '1st Half', 'odd': '2.70'},
#         {'value': '2nd Half', 'odd': '2.20'}]},
#       {'id': 31,
#        'name': 'Correct Score - First Half',
#        'values': [{'value': '1:0', 'odd': '9.00'},
#         {'value': '2:0', 'odd': '41.00'},
#         {'value': '2:1', 'odd': '41.00'},
#         {'value': '3:0', 'odd': '81.00'},
#         {'value': '0:0', 'odd': '2.80'},
#         {'value': '1:1', 'odd': '9.00'},
#         {'value': '2:2', 'odd': '56.00'},
#         {'value': '0:1', 'odd': '3.10'},
#         {'value': '0:2', 'odd': '6.50'},
#         {'value': '0:3', 'odd': '19.00'},
#         {'value': '0:4', 'odd': '46.00'},
#         {'value': '0:5', 'odd': '71.00'},
#         {'value': '1:2', 'odd': '19.00'},
#         {'value': '1:3', 'odd': '41.00'},
#         {'value': '1:4', 'odd': '71.00'},
#         {'value': '2:3', 'odd': '81.00'}]},
#       {'id': 12,
#        'name': 'Double Chance',
#        'values': [{'value': 'Home/Draw', 'odd': '3.00'},
#         {'value': 'Home/Away', 'odd': '1.20'},
#         {'value': 'Draw/Away', 'odd': '1.04'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.00'},
#         {'value': 'Draw', 'odd': '2.30'},
#         {'value': 'Away', 'odd': '1.83'}]},
#       {'id': 32,
#        'name': 'Win Both Halves',
#        'values': [{'value': 'Home', 'odd': '29.00'},
#         {'value': 'Away', 'odd': '3.25'}]},
#       {'id': 20,
#        'name': 'Double Chance - First Half',
#        'values': [{'value': 'Home/Draw', 'odd': '1.83'},
#         {'value': 'Home/Away', 'odd': '1.55'},
#         {'value': 'Draw/Away', 'odd': '1.06'}]},
#       {'id': 33,
#        'name': 'Double Chance - Second Half',
#        'values': [{'value': 'Home/Draw', 'odd': '1.95'},
#         {'value': 'Home/Away', 'odd': '1.50'},
#         {'value': 'Draw/Away', 'odd': '1.06'}]},
#       {'id': 34,
#        'name': 'Both Teams Score - First Half',
#        'values': [{'value': 'Yes', 'odd': '5.00'},
#         {'value': 'No', 'odd': '1.14'}]},
#       {'id': 35,
#        'name': 'Both Teams To Score - Second Half',
#        'values': [{'value': 'Yes', 'odd': '4.33'},
#         {'value': 'No', 'odd': '1.20'}]},
#       {'id': 36,
#        'name': 'Win To Nil',
#        'values': [{'value': 'Home', 'odd': '13.00'},
#         {'value': 'Away', 'odd': '1.91'}]},
#       {'id': 53,
#        'name': 'Away win both halves',
#        'values': [{'value': 'Yes', 'odd': '3.40'},
#         {'value': 'No', 'odd': '1.30'}]},
#       {'id': 39,
#        'name': 'To Win Either Half',
#        'values': [{'value': 'Home', 'odd': '4.33'},
#         {'value': 'Away', 'odd': '1.22'}]},
#       {'id': 24,
#        'name': 'Results/Both Teams Score',
#        'values': [{'value': 'Home/Yes', 'odd': '19.00'},
#         {'value': 'Draw/Yes', 'odd': '6.50'},
#         {'value': 'Away/Yes', 'odd': '3.80'}]},
#       {'id': 188,
#        'name': 'Clean Sheet',
#        'values': [{'value': 'Home', 'odd': '6.50'},
#         {'value': 'Away', 'odd': '1.67'}]},
#       {'id': 114,
#        'name': 'Home Team Score a Goal (1st Half)',
#        'values': [{'value': 'Yes', 'odd': '3.40'},
#         {'value': 'No', 'odd': '1.30'}]},
#       {'id': 115,
#        'name': 'Home Team Score a Goal (2nd Half)',
#        'values': [{'value': 'Yes', 'odd': '3.25'},
#         {'value': 'No', 'odd': '1.33'}]},
#       {'id': 116,
#        'name': 'Away Team Score a Goal (1st Half)',
#        'values': [{'value': 'Yes', 'odd': '1.57'},
#         {'value': 'No', 'odd': '2.30'}]},
#       {'id': 117,
#        'name': 'Away Team Score a Goal (2nd Half)',
#        'values': [{'value': 'Yes', 'odd': '1.50'},
#         {'value': 'No', 'odd': '2.50'}]},
#       {'id': 192,
#        'name': 'Home Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '1.55'},
#         {'value': '1st Half', 'odd': '4.40'},
#         {'value': '2nd Half', 'odd': '3.90'}]},
#       {'id': 193,
#        'name': 'Away Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '2.88'},
#         {'value': '1st Half', 'odd': '2.88'},
#         {'value': '2nd Half', 'odd': '2.30'}]}]},
#     {'id': 8,
#      'name': 'Bet365',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '8.00'},
#         {'value': 'Draw', 'odd': '4.10'},
#         {'value': 'Away', 'odd': '1.38'}]},
#       {'id': 2,
#        'name': 'Home/Away',
#        'values': [{'value': 'Home', 'odd': '6.00'},
#         {'value': 'Away', 'odd': '1.11'}]},
#       {'id': 3,
#        'name': 'Second Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.00'},
#         {'value': 'Draw', 'odd': '2.62'},
#         {'value': 'Away', 'odd': '1.67'}]},
#       {'id': 4,
#        'name': 'Asian Handicap',
#        'values': [{'value': 'Home +0', 'odd': '6.40'},
#         {'value': 'Away +0', 'odd': '1.12'},
#         {'value': 'Home -0.25', 'odd': '7.00'},
#         {'value': 'Away -0.25', 'odd': '1.10'},
#         {'value': 'Home +0.25', 'odd': '3.80'},
#         {'value': 'Away +0.25', 'odd': '1.25'},
#         {'value': 'Home +0.5', 'odd': '2.85'},
#         {'value': 'Away +0.5', 'odd': '1.40'},
#         {'value': 'Home +0.75', 'odd': '2.60'},
#         {'value': 'Away +0.75', 'odd': '1.48'},
#         {'value': 'Home +1', 'odd': '2.25'},
#         {'value': 'Away +1', 'odd': '1.62'},
#         {'value': 'Home +1.5', 'odd': '1.68'},
#         {'value': 'Away +1.5', 'odd': '2.15'},
#         {'value': 'Home +1.25', 'odd': '1.90'},
#         {'value': 'Away +1.25', 'odd': '1.90'},
#         {'value': 'Home +1.75', 'odd': '1.52'},
#         {'value': 'Away +1.75', 'odd': '2.42'},
#         {'value': 'Home +2', 'odd': '1.35'},
#         {'value': 'Away +2', 'odd': '3.10'},
#         {'value': 'Home +3', 'odd': '1.10'},
#         {'value': 'Away +3', 'odd': '7.00'},
#         {'value': 'Home +2.5', 'odd': '1.25'},
#         {'value': 'Away +2.5', 'odd': '3.80'},
#         {'value': 'Home +2.25', 'odd': '1.30'},
#         {'value': 'Away +2.25', 'odd': '3.45'},
#         {'value': 'Home +2.75', 'odd': '1.17'},
#         {'value': 'Away +2.75', 'odd': '5.00'}]},
#       {'id': 5,
#        'name': 'Goals Over/Under',
#        'values': [{'value': 'Over 3.5', 'odd': '3.40'},
#         {'value': 'Under 3.5', 'odd': '1.30'},
#         {'value': 'Over 1.5', 'odd': '1.28'},
#         {'value': 'Under 1.5', 'odd': '3.50'},
#         {'value': 'Over 4.5', 'odd': '6.00'},
#         {'value': 'Under 4.5', 'odd': '1.11'},
#         {'value': 'Over 2.5', 'odd': '1.95'},
#         {'value': 'Under 2.5', 'odd': '1.85'},
#         {'value': 'Over 0.5', 'odd': '1.05'},
#         {'value': 'Under 0.5', 'odd': '8.50'},
#         {'value': 'Over 5.5', 'odd': '10.00'},
#         {'value': 'Under 5.5', 'odd': '1.03'},
#         {'value': 'Over 6.5', 'odd': '15.00'},
#         {'value': 'Under 6.5', 'odd': '1.01'},
#         {'value': 'Over 7.5', 'odd': '21.00'}]},
#       {'id': 6,
#        'name': 'Goals Over/Under First Half',
#        'values': [{'value': 'Over 3.5', 'odd': '12.00'},
#         {'value': 'Under 3.5', 'odd': '1.01'},
#         {'value': 'Over 1.5', 'odd': '2.75'},
#         {'value': 'Under 1.5', 'odd': '1.40'},
#         {'value': 'Over 2.5', 'odd': '7.00'},
#         {'value': 'Under 2.5', 'odd': '1.08'},
#         {'value': 'Over 0.5', 'odd': '1.40'},
#         {'value': 'Under 0.5', 'odd': '2.75'}]},
#       {'id': 26,
#        'name': 'Goals Over/Under - Second Half',
#        'values': [{'value': 'Over 3.5', 'odd': '13.00'},
#         {'value': 'Under 3.5', 'odd': '1.04'},
#         {'value': 'Over 1.5', 'odd': '2.10'},
#         {'value': 'Under 1.5', 'odd': '1.67'},
#         {'value': 'Over 2.5', 'odd': '4.50'},
#         {'value': 'Under 2.5', 'odd': '1.18'},
#         {'value': 'Over 0.5', 'odd': '1.25'},
#         {'value': 'Under 0.5', 'odd': '3.75'}]},
#       {'id': 7,
#        'name': 'HT/FT Double',
#        'values': [{'value': 'Home/Draw', 'odd': '21.00'},
#         {'value': 'Home/Away', 'odd': '23.00'},
#         {'value': 'Draw/Away', 'odd': '3.75'},
#         {'value': 'Draw/Draw', 'odd': '6.00'},
#         {'value': 'Home/Home', 'odd': '13.00'},
#         {'value': 'Draw/Home', 'odd': '15.00'},
#         {'value': 'Away/Home', 'odd': '51.00'},
#         {'value': 'Away/Draw', 'odd': '21.00'},
#         {'value': 'Away/Away', 'odd': '2.05'}]},
#       {'id': 27,
#        'name': 'Clean Sheet - Home',
#        'values': [{'value': 'Yes', 'odd': '5.50'},
#         {'value': 'No', 'odd': '1.12'}]},
#       {'id': 28,
#        'name': 'Clean Sheet - Away',
#        'values': [{'value': 'Yes', 'odd': '1.73'},
#         {'value': 'No', 'odd': '2.00'}]},
#       {'id': 8,
#        'name': 'Both Teams Score',
#        'values': [{'value': 'Yes', 'odd': '2.25'},
#         {'value': 'No', 'odd': '1.57'}]},
#       {'id': 9,
#        'name': 'Handicap Result',
#        'values': [{'value': 'Home -1', 'odd': '23.00'},
#         {'value': 'Away -1', 'odd': '1.06'},
#         {'value': 'Draw -1', 'odd': '11.00'},
#         {'value': 'Home +1', 'odd': '3.00'},
#         {'value': 'Away +1', 'odd': '2.10'},
#         {'value': 'Draw +1', 'odd': '3.50'},
#         {'value': 'Home +2', 'odd': '1.67'},
#         {'value': 'Draw +2', 'odd': '4.00'},
#         {'value': 'Away +2', 'odd': '3.75'},
#         {'value': 'Home -2', 'odd': '51.00'},
#         {'value': 'Draw -2', 'odd': '26.00'},
#         {'value': 'Away -2', 'odd': '1.01'},
#         {'value': 'Home +3', 'odd': '1.22'},
#         {'value': 'Draw +3', 'odd': '6.00'},
#         {'value': 'Away +3', 'odd': '7.50'}]},
#       {'id': 10,
#        'name': 'Exact Score',
#        'values': [{'value': '1:0', 'odd': '17.00'},
#         {'value': '2:0', 'odd': '41.00'},
#         {'value': '2:1', 'odd': '26.00'},
#         {'value': '3:0', 'odd': '101.00'},
#         {'value': '3:1', 'odd': '67.00'},
#         {'value': '3:2', 'odd': '67.00'},
#         {'value': '0:0', 'odd': '9.50'},
#         {'value': '1:1', 'odd': '8.50'},
#         {'value': '2:2', 'odd': '23.00'},
#         {'value': '3:3', 'odd': '81.00'},
#         {'value': '0:1', 'odd': '6.00'},
#         {'value': '0:2', 'odd': '6.00'},
#         {'value': '0:3', 'odd': '8.50'},
#         {'value': '0:4', 'odd': '15.00'},
#         {'value': '0:5', 'odd': '34.00'},
#         {'value': '0:6', 'odd': '51.00'},
#         {'value': '1:2', 'odd': '9.00'},
#         {'value': '1:3', 'odd': '13.00'},
#         {'value': '1:4', 'odd': '23.00'},
#         {'value': '1:5', 'odd': '41.00'},
#         {'value': '1:6', 'odd': '81.00'},
#         {'value': '2:3', 'odd': '34.00'},
#         {'value': '2:4', 'odd': '51.00'},
#         {'value': '2:5', 'odd': '81.00'},
#         {'value': '3:4', 'odd': '126.00'},
#         {'value': '0:7', 'odd': '126.00'}]},
#       {'id': 11,
#        'name': 'Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '3.50'},
#         {'value': '1st Half', 'odd': '3.10'},
#         {'value': '2nd Half', 'odd': '2.05'}]},
#       {'id': 31,
#        'name': 'Correct Score - First Half',
#        'values': [{'value': '1:0', 'odd': '9.00'},
#         {'value': '2:0', 'odd': '41.00'},
#         {'value': '2:1', 'odd': '41.00'},
#         {'value': '3:0', 'odd': '151.00'},
#         {'value': '0:0', 'odd': '2.75'},
#         {'value': '1:1', 'odd': '10.00'},
#         {'value': '2:2', 'odd': '67.00'},
#         {'value': '0:1', 'odd': '3.25'},
#         {'value': '0:2', 'odd': '7.00'},
#         {'value': '0:3', 'odd': '19.00'},
#         {'value': '0:4', 'odd': '51.00'},
#         {'value': '0:5', 'odd': '151.00'},
#         {'value': '1:2', 'odd': '21.00'},
#         {'value': '1:3', 'odd': '51.00'},
#         {'value': '1:4', 'odd': '126.00'},
#         {'value': '2:3', 'odd': '151.00'}]},
#       {'id': 12,
#        'name': 'Double Chance',
#        'values': [{'value': 'Home/Draw', 'odd': '3.00'},
#         {'value': 'Home/Away', 'odd': '1.22'},
#         {'value': 'Draw/Away', 'odd': '1.06'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.50'},
#         {'value': 'Draw', 'odd': '2.25'},
#         {'value': 'Away', 'odd': '1.91'}]},
#       {'id': 14,
#        'name': 'Team To Score First',
#        'values': [{'value': 'Home', 'odd': '4.50'},
#         {'value': 'Draw', 'odd': '9.50'},
#         {'value': 'Away', 'odd': '1.28'}]},
#       {'id': 15,
#        'name': 'Team To Score Last',
#        'values': [{'value': 'Home', 'odd': '4.50'},
#         {'value': 'Draw', 'odd': '9.50'},
#         {'value': 'Away', 'odd': '1.28'}]},
#       {'id': 32,
#        'name': 'Win Both Halves',
#        'values': [{'value': 'Home', 'odd': '34.00'},
#         {'value': 'Away', 'odd': '3.40'}]},
#       {'id': 16,
#        'name': 'Total - Home',
#        'values': [{'value': 'Over 1.5', 'odd': '6.00'},
#         {'value': 'Under 1.5', 'odd': '1.11'},
#         {'value': 'Over 2.5', 'odd': '12.00'},
#         {'value': 'Under 2.5', 'odd': '1.01'},
#         {'value': 'Over 0.5', 'odd': '2.00'},
#         {'value': 'Under 0.5', 'odd': '1.73'}]},
#       {'id': 17,
#        'name': 'Total - Away',
#        'values': [{'value': 'Over 3.5', 'odd': '5.50'},
#         {'value': 'Under 3.5', 'odd': '1.12'},
#         {'value': 'Over 1.5', 'odd': '1.57'},
#         {'value': 'Under 1.5', 'odd': '2.25'},
#         {'value': 'Over 4.5', 'odd': '9.00'},
#         {'value': 'Under 4.5', 'odd': '1.04'},
#         {'value': 'Over 2.5', 'odd': '2.75'},
#         {'value': 'Under 2.5', 'odd': '1.40'},
#         {'value': 'Over 0.5', 'odd': '1.12'},
#         {'value': 'Under 0.5', 'odd': '5.50'},
#         {'value': 'Over 5.5', 'odd': '17.00'},
#         {'value': 'Under 5.5', 'odd': '1.01'}]},
#       {'id': 18,
#        'name': 'Handicap Result - First Half',
#        'values': [{'value': 'Home -1', 'odd': '41.00'},
#         {'value': 'Away -1', 'odd': '1.07'},
#         {'value': 'Draw -1', 'odd': '8.50'},
#         {'value': 'Home +1', 'odd': '1.80'},
#         {'value': 'Away +1', 'odd': '4.75'},
#         {'value': 'Draw +1', 'odd': '2.88'},
#         {'value': 'Home +2', 'odd': '1.14'},
#         {'value': 'Draw +2', 'odd': '6.00'},
#         {'value': 'Away +2', 'odd': '13.00'},
#         {'value': 'Home +3', 'odd': '1.03'},
#         {'value': 'Draw +3', 'odd': '17.00'},
#         {'value': 'Away +3', 'odd': '41.00'}]},
#       {'id': 19,
#        'name': 'Asian Handicap First Half',
#        'values': [{'value': 'Home +0', 'odd': '4.50'},
#         {'value': 'Away +0', 'odd': '1.19'},
#         {'value': 'Home -0.25', 'odd': '5.90'},
#         {'value': 'Away -0.25', 'odd': '1.13'},
#         {'value': 'Home +0.25', 'odd': '2.35'},
#         {'value': 'Away +0.25', 'odd': '1.58'},
#         {'value': 'Home -0.5', 'odd': '7.00'},
#         {'value': 'Away -0.5', 'odd': '1.10'},
#         {'value': 'Home +0.5', 'odd': '1.82'},
#         {'value': 'Away +0.5', 'odd': '1.98'},
#         {'value': 'Home +0.75', 'odd': '1.55'},
#         {'value': 'Away +0.75', 'odd': '2.38'},
#         {'value': 'Home +1', 'odd': '1.30'},
#         {'value': 'Away +1', 'odd': '3.45'},
#         {'value': 'Home +1.5', 'odd': '1.18'},
#         {'value': 'Away +1.5', 'odd': '4.80'},
#         {'value': 'Home +1.25', 'odd': '1.22'},
#         {'value': 'Away +1.25', 'odd': '4.15'},
#         {'value': 'Home +1.75', 'odd': '1.10'},
#         {'value': 'Away +1.75', 'odd': '6.80'}]},
#       {'id': 20,
#        'name': 'Double Chance - First Half',
#        'values': [{'value': 'Home/Draw', 'odd': '1.80'},
#         {'value': 'Home/Away', 'odd': '1.57'},
#         {'value': 'Draw/Away', 'odd': '1.07'}]},
#       {'id': 34,
#        'name': 'Both Teams Score - First Half',
#        'values': [{'value': 'Yes', 'odd': '6.00'},
#         {'value': 'No', 'odd': '1.12'}]},
#       {'id': 35,
#        'name': 'Both Teams To Score - Second Half',
#        'values': [{'value': 'Yes', 'odd': '4.33'},
#         {'value': 'No', 'odd': '1.20'}]},
#       {'id': 36,
#        'name': 'Win To Nil',
#        'values': [{'value': 'Home', 'odd': '13.00'},
#         {'value': 'Away', 'odd': '2.00'}]},
#       {'id': 21,
#        'name': 'Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '1.98'},
#         {'value': 'Even', 'odd': '1.88'}]},
#       {'id': 22,
#        'name': 'Odd/Even - First Half',
#        'values': [{'value': 'Odd', 'odd': '2.10'},
#         {'value': 'Even', 'odd': '1.73'}]},
#       {'id': 23,
#        'name': 'Home Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '2.62'},
#         {'value': 'Even', 'odd': '1.44'}]},
#       {'id': 60,
#        'name': 'Away Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '1.83'},
#         {'value': 'Even', 'odd': '1.83'}]},
#       {'id': 38,
#        'name': 'Exact Goals Number',
#        'values': [{'value': 2, 'odd': '3.60'},
#         {'value': 3, 'odd': '4.33'},
#         {'value': 4, 'odd': '6.00'},
#         {'value': 1, 'odd': '4.75'},
#         {'value': 0, 'odd': '9.50'},
#         {'value': 5, 'odd': '11.00'},
#         {'value': 6, 'odd': '21.00'},
#         {'value': 'more 7', 'odd': '15.00'}]},
#       {'id': 39,
#        'name': 'To Win Either Half',
#        'values': [{'value': 'Home', 'odd': '4.00'},
#         {'value': 'Away', 'odd': '1.25'}]},
#       {'id': 40,
#        'name': 'Home Team Exact Goals Number',
#        'values': [{'value': 2, 'odd': '7.50'},
#         {'value': 1, 'odd': '2.62'},
#         {'value': 0, 'odd': '1.73'},
#         {'value': 'more 3', 'odd': '12.00'}]},
#       {'id': 41,
#        'name': 'Away Team Exact Goals Number',
#        'values': [{'value': 2, 'odd': '3.40'},
#         {'value': 1, 'odd': '3.25'},
#         {'value': 0, 'odd': '5.50'},
#         {'value': 'more 3', 'odd': '2.75'}]},
#       {'id': 42,
#        'name': 'Second Half Exact Goals Number',
#        'values': [{'value': 2, 'odd': '3.60'},
#         {'value': 3, 'odd': '7.00'},
#         {'value': 4, 'odd': '17.00'},
#         {'value': 1, 'odd': '2.75'},
#         {'value': 0, 'odd': '3.75'},
#         {'value': 'more 5', 'odd': '29.00'}]},
#       {'id': 24,
#        'name': 'Results/Both Teams Score',
#        'values': [{'value': 'Home/Yes', 'odd': '17.00'},
#         {'value': 'Draw/Yes', 'odd': '6.50'},
#         {'value': 'Away/Yes', 'odd': '3.75'},
#         {'value': 'Home/No', 'odd': '13.00'},
#         {'value': 'Draw/No', 'odd': '9.50'},
#         {'value': 'Away/No', 'odd': '2.00'}]},
#       {'id': 25,
#        'name': 'Result/Total Goals',
#        'values': [{'value': 'Home/Over 2.5', 'odd': '17.00'},
#         {'value': 'Draw/Over 2.5', 'odd': '21.00'},
#         {'value': 'Away/Over 2.5', 'odd': '2.25'},
#         {'value': 'Home/Under 2.5', 'odd': '13.00'},
#         {'value': 'Draw/Under 2.5', 'odd': '5.00'},
#         {'value': 'Away/Under 2.5', 'odd': '3.20'}]},
#       {'id': 45,
#        'name': 'Corners Over Under',
#        'values': [{'value': 'Over 9.5', 'odd': '2.10'},
#         {'value': 'Under 9.5', 'odd': '1.67'},
#         {'value': 'Over 9', 'odd': '1.85'},
#         {'value': 'Under 9', 'odd': '1.95'}]},
#       {'id': 46,
#        'name': 'Exact Goals Number - First Half',
#        'values': [{'value': 2, 'odd': '4.33'},
#         {'value': 3, 'odd': '10.00'},
#         {'value': 4, 'odd': '29.00'},
#         {'value': 1, 'odd': '2.60'},
#         {'value': 0, 'odd': '2.75'},
#         {'value': 'more 5', 'odd': '21.00'}]},
#       {'id': 63,
#        'name': 'Odd/Even - Second Half',
#        'values': [{'value': 'Odd', 'odd': '1.91'},
#         {'value': 'Even', 'odd': '1.80'}]},
#       {'id': 47,
#        'name': 'Winning Margin',
#        'values': [{'value': 'Draw', 'odd': '9.50'},
#         {'value': '1 by 1', 'odd': '11.00'},
#         {'value': '2 by 1', 'odd': '3.50'},
#         {'value': '1 by 2', 'odd': '26.00'},
#         {'value': '2 by 2', 'odd': '4.00'},
#         {'value': '1 by 3', 'odd': '81.00'},
#         {'value': '2 by 3', 'odd': '6.00'},
#         {'value': '1 by 4+', 'odd': '301.00'},
#         {'value': '2 by 4+', 'odd': '7.50'},
#         {'value': 'Score Draw', 'odd': '6.50'}]},
#       {'id': 48,
#        'name': 'To Score In Both Halves By Teams',
#        'values': [{'value': 'Home', 'odd': '11.00'},
#         {'value': 'Away', 'odd': '2.38'}]},
#       {'id': 49,
#        'name': 'Total Goals/Both Teams To Score',
#        'values': [{'value': 'o/yes 2.5', 'odd': '2.88'},
#         {'value': 'o/no 2.5', 'odd': '4.75'},
#         {'value': 'u/yes 2.5', 'odd': '9.00'},
#         {'value': 'u/no 2.5', 'odd': '2.20'}]},
#       {'id': 50,
#        'name': 'Goal Line',
#        'values': [{'value': 'Over 3.5', 'odd': '3.30'},
#         {'value': 'Under 3.5', 'odd': '1.32'},
#         {'value': 'Over 1.5', 'odd': '1.30'},
#         {'value': 'Under 1.5', 'odd': '3.45'},
#         {'value': 'Over 4.5', 'odd': '6.40'},
#         {'value': 'Under 4.5', 'odd': '1.12'},
#         {'value': 'Over 2.5', 'odd': '1.95'},
#         {'value': 'Under 2.5', 'odd': '1.85'},
#         {'value': 'Over 2', 'odd': '1.45'},
#         {'value': 'Under 2', 'odd': '2.68'},
#         {'value': 'Over 3', 'odd': '2.60'},
#         {'value': 'Under 3', 'odd': '1.48'},
#         {'value': 'Over 4', 'odd': '5.75'},
#         {'value': 'Under 4', 'odd': '1.14'},
#         {'value': 'Over 2.25', 'odd': '1.70'},
#         {'value': 'Under 2.25', 'odd': '2.10'},
#         {'value': 'Over 3.25', 'odd': '3.00'},
#         {'value': 'Under 3.25', 'odd': '1.38'},
#         {'value': 'Over 2.75', 'odd': '2.20'},
#         {'value': 'Under 2.75', 'odd': '1.65'},
#         {'value': 'Over 1.25', 'odd': '1.18'},
#         {'value': 'Under 1.25', 'odd': '4.65'},
#         {'value': 'Over 4.25', 'odd': '5.90'},
#         {'value': 'Under 4.25', 'odd': '1.13'},
#         {'value': 'Over 1.75', 'odd': '1.35'},
#         {'value': 'Under 1.75', 'odd': '3.10'},
#         {'value': 'Over 3.75', 'odd': '4.00'},
#         {'value': 'Under 3.75', 'odd': '1.23'}]},
#       {'id': 72,
#        'name': 'Goal Line (1st Half)',
#        'values': [{'value': 'Over 1.5', 'odd': '2.85'},
#         {'value': 'Under 1.5', 'odd': '1.40'},
#         {'value': 'Over 0.5', 'odd': '1.40'},
#         {'value': 'Under 0.5', 'odd': '2.85'},
#         {'value': 'Over 2', 'odd': '5.90'},
#         {'value': 'Under 2', 'odd': '1.13'},
#         {'value': 'Over 2.25', 'odd': '6.60'},
#         {'value': 'Under 2.25', 'odd': '1.11'},
#         {'value': 'Over 1.25', 'odd': '2.35'},
#         {'value': 'Under 1.25', 'odd': '1.58'},
#         {'value': 'Over 1.75', 'odd': '3.55'},
#         {'value': 'Under 1.75', 'odd': '1.27'},
#         {'value': 'Over 1', 'odd': '1.90'},
#         {'value': 'Under 1', 'odd': '1.90'},
#         {'value': 'Over 0.75', 'odd': '1.55'},
#         {'value': 'Under 0.75', 'odd': '2.38'}]},
#       {'id': 52,
#        'name': 'Halftime Result/Both Teams Score',
#        'values': [{'value': 'Home/Yes', 'odd': '41.00'},
#         {'value': 'Draw/Yes', 'odd': '9.50'},
#         {'value': 'Away/Yes', 'odd': '15.00'},
#         {'value': 'Home/No', 'odd': '8.00'},
#         {'value': 'Draw/No', 'odd': '2.75'},
#         {'value': 'Away/No', 'odd': '2.10'}]},
#       {'id': 85,
#        'name': 'Total Corners (3 way)',
#        'values': [{'value': 'Over 4', 'odd': '1.03'},
#         {'value': 'Under 4', 'odd': '23.00'},
#         {'value': 'Exactly 4', 'odd': '17.00'},
#         {'value': 'Over 5', 'odd': '1.08'},
#         {'value': 'Under 5', 'odd': '15.00'},
#         {'value': 'Exactly 5', 'odd': '13.00'},
#         {'value': 'Over 6', 'odd': '1.20'},
#         {'value': 'Under 6', 'odd': '8.00'},
#         {'value': 'Exactly 6', 'odd': '9.50'},
#         {'value': 'Over 7', 'odd': '1.36'},
#         {'value': 'Under 7', 'odd': '4.33'},
#         {'value': 'Exactly 7', 'odd': '8.00'},
#         {'value': 'Over 8', 'odd': '1.62'},
#         {'value': 'Under 8', 'odd': '3.00'},
#         {'value': 'Exactly 8', 'odd': '7.50'},
#         {'value': 'Over 9', 'odd': '2.10'},
#         {'value': 'Under 9', 'odd': '2.20'},
#         {'value': 'Exactly 9', 'odd': '7.50'},
#         {'value': 'Over 10', 'odd': '2.75'},
#         {'value': 'Under 10', 'odd': '1.67'},
#         {'value': 'Exactly 10', 'odd': '8.50'},
#         {'value': 'Over 11', 'odd': '3.75'},
#         {'value': 'Under 11', 'odd': '1.40'},
#         {'value': 'Exactly 11', 'odd': '9.50'},
#         {'value': 'Over 13', 'odd': '8.00'},
#         {'value': 'Under 13', 'odd': '1.14'},
#         {'value': 'Exactly 13', 'odd': '15.00'},
#         {'value': 'Over 14', 'odd': '13.00'},
#         {'value': 'Under 14', 'odd': '1.08'},
#         {'value': 'Exactly 14', 'odd': '19.00'},
#         {'value': 'Over 12', 'odd': '5.50'},
#         {'value': 'Under 12', 'odd': '1.25'},
#         {'value': 'Exactly 12', 'odd': '11.00'},
#         {'value': 'Over 15', 'odd': '17.00'},
#         {'value': 'Under 15', 'odd': '1.04'},
#         {'value': 'Exactly 15', 'odd': '21.00'},
#         {'value': 'Over 16', 'odd': '23.00'},
#         {'value': 'Under 16', 'odd': '1.02'},
#         {'value': 'Exactly 16', 'odd': '29.00'}]},
#       {'id': 73,
#        'name': 'Both Teams to Score 1st Half - 2nd Half',
#        'values': [{'value': 'Yes/Yes', 'odd': '26.00'},
#         {'value': 'Yes/No', 'odd': '7.00'},
#         {'value': 'No/Yes', 'odd': '4.75'},
#         {'value': 'No/No', 'odd': '1.36'}]},
#       {'id': 77,
#        'name': 'Total Corners (1st Half)',
#        'values': [{'value': 'Over 4.5', 'odd': '2.05'},
#         {'value': 'Under 4.5', 'odd': '1.75'}]},
#       {'id': 84,
#        'name': 'Total Corners (3 way) (1st Half)',
#        'values': [{'value': 'Over 4', 'odd': '2.00'},
#         {'value': 'Under 4', 'odd': '2.60'},
#         {'value': 'Exactly 4', 'odd': '5.00'}]},
#       {'id': 78,
#        'name': 'RTG_H1',
#        'values': [{'value': 'Home/Over 1.5', 'odd': '26.00'},
#         {'value': 'Away/Over 1.5', 'odd': '4.00'},
#         {'value': 'Draw/Over 1.5', 'odd': '10.00'},
#         {'value': 'Draw/Under 1.5', 'odd': '2.75'},
#         {'value': 'Home/Under 1.5', 'odd': '9.00'},
#         {'value': 'Away/Under 1.5', 'odd': '3.25'}]},
#       {'id': 192,
#        'name': 'Home Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '1.62'},
#         {'value': '1st Half', 'odd': '4.75'},
#         {'value': '2nd Half', 'odd': '3.60'}]},
#       {'id': 193,
#        'name': 'Away Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '2.88'},
#         {'value': '1st Half', 'odd': '3.10'},
#         {'value': '2nd Half', 'odd': '2.20'}]}]},
#     {'id': 2,
#      'name': 'Marathonbet',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '8.40'},
#         {'value': 'Draw', 'odd': '4.55'},
#         {'value': 'Away', 'odd': '1.34'}]},
#       {'id': 3,
#        'name': 'Second Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.20'},
#         {'value': 'Draw', 'odd': '2.71'},
#         {'value': 'Away', 'odd': '1.64'}]},
#       {'id': 4,
#        'name': 'Asian Handicap',
#        'values': [{'value': 'Home +0', 'odd': '6.30'},
#         {'value': 'Away +0', 'odd': '1.07'},
#         {'value': 'Home -0.25', 'odd': '6.85'},
#         {'value': 'Away -0.25', 'odd': '1.06'},
#         {'value': 'Home +0.25', 'odd': '3.90'},
#         {'value': 'Away +0.25', 'odd': '1.20'},
#         {'value': 'Home -0.75', 'odd': '10.00'},
#         {'value': 'Away -0.75', 'odd': '1.01'},
#         {'value': 'Home +0.75', 'odd': '2.62'},
#         {'value': 'Away +0.75', 'odd': '1.41'},
#         {'value': 'Home +1', 'odd': '2.32'},
#         {'value': 'Away +1', 'odd': '1.57'},
#         {'value': 'Home +1.5', 'odd': '1.66'},
#         {'value': 'Away +1.5', 'odd': '2.04'},
#         {'value': 'Home +1.25', 'odd': '1.86'},
#         {'value': 'Away +1.25', 'odd': '1.81'},
#         {'value': 'Home +1.75', 'odd': '1.49'},
#         {'value': 'Away +1.75', 'odd': '2.38'},
# ...
#         {'value': 'Over 1.5', 'odd': '1.57'},
#         {'value': 'Under 1.5', 'odd': '2.25'},
#         {'value': 'Over 4.5', 'odd': '11.00'},
#         {'value': 'Under 4.5', 'odd': '1.01'},
#         {'value': 'Over 2.5', 'odd': '2.80'},
#         {'value': 'Under 2.5', 'odd': '1.38'},
#         {'value': 'Over 0.5', 'odd': '1.10'},
#         {'value': 'Under 0.5', 'odd': '5.75'}]},
#       {'id': 20,
#        'name': 'Double Chance - First Half',
#        'values': [{'value': 'Home/Draw', 'odd': '1.85'},
#         {'value': 'Home/Away', 'odd': '1.55'},
#         {'value': 'Draw/Away', 'odd': '1.09'}]},
#       {'id': 33,
#        'name': 'Double Chance - Second Half',
#        'values': [{'value': 'Home/Draw', 'odd': '2.05'},
#         {'value': 'Home/Away', 'odd': '1.45'},
#         {'value': 'Draw/Away', 'odd': '1.08'}]},
#       {'id': 34,
#        'name': 'Both Teams Score - First Half',
#        'values': [{'value': 'Yes', 'odd': '5.50'},
#         {'value': 'No', 'odd': '1.11'}]},
#       {'id': 35,
#        'name': 'Both Teams To Score - Second Half',
#        'values': [{'value': 'Yes', 'odd': '4.00'},
#         {'value': 'No', 'odd': '1.20'}]},
#       {'id': 21,
#        'name': 'Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '1.85'},
#         {'value': 'Even', 'odd': '1.85'}]},
#       {'id': 39,
#        'name': 'To Win Either Half',
#        'values': [{'value': 'Home', 'odd': '4.00'},
#         {'value': 'Away', 'odd': '1.22'}]},
#       {'id': 24,
#        'name': 'Results/Both Teams Score',
#        'values': [{'value': 'Home/Yes', 'odd': '15.00'},
#         {'value': 'Draw/Yes', 'odd': '6.50'},
#         {'value': 'Away/Yes', 'odd': '3.60'},
#         {'value': 'Home/No', 'odd': '11.00'},
#         {'value': 'Draw/No', 'odd': '10.00'},
#         {'value': 'Away/No', 'odd': '2.05'}]},
#       {'id': 25,
#        'name': 'Result/Total Goals',
#        'values': [{'value': 'Home/Over 3.5', 'odd': '34.00'},
#         {'value': 'Draw/Over 3.5', 'odd': '19.00'},
#         {'value': 'Away/Over 3.5', 'odd': '4.00'},
#         {'value': 'Home/Under 3.5', 'odd': '8.50'},
#         {'value': 'Draw/Under 3.5', 'odd': '5.25'},
#         {'value': 'Away/Under 3.5', 'odd': '1.95'},
#         {'value': 'Home/Over 1.5', 'odd': '12.00'},
#         {'value': 'Away/Over 1.5', 'odd': '1.70'},
#         {'value': 'Draw/Over 1.5', 'odd': '6.50'},
#         {'value': 'Draw/Under 1.5', 'odd': '10.00'},
#         {'value': 'Home/Under 1.5', 'odd': '13.00'},
#         {'value': 'Away/Under 1.5', 'odd': '5.75'},
#         {'value': 'Home/Over 4.5', 'odd': '51.00'},
#         {'value': 'Draw/Over 4.5', 'odd': '81.00'},
#         {'value': 'Away/Over 4.5', 'odd': '7.00'},
#         {'value': 'Home/Under 4.5', 'odd': '8.00'},
#         {'value': 'Draw/Under 4.5', 'odd': '4.50'},
#         {'value': 'Away/Under 4.5', 'odd': '1.62'},
#         {'value': 'Home/Over 2.5', 'odd': '13.00'},
#         {'value': 'Draw/Over 2.5', 'odd': '19.00'},
#         {'value': 'Away/Over 2.5', 'odd': '2.25'},
#         {'value': 'Home/Under 2.5', 'odd': '12.00'},
#         {'value': 'Draw/Under 2.5', 'odd': '5.25'},
#         {'value': 'Away/Under 2.5', 'odd': '3.10'}]},
#       {'id': 45,
#        'name': 'Corners Over Under',
#        'values': [{'value': 'Over 5.5', 'odd': '1.10'},
#         {'value': 'Under 5.5', 'odd': '5.75'},
#         {'value': 'Over 6.5', 'odd': '1.22'},
#         {'value': 'Under 6.5', 'odd': '3.80'},
#         {'value': 'Over 9.5', 'odd': '2.10'},
#         {'value': 'Under 9.5', 'odd': '1.67'},
#         {'value': 'Over 10.5', 'odd': '2.62'},
#         {'value': 'Under 10.5', 'odd': '1.42'},
#         {'value': 'Over 7.5', 'odd': '1.40'},
#         {'value': 'Under 7.5', 'odd': '2.70'},
#         {'value': 'Over 11.5', 'odd': '3.60'},
#         {'value': 'Under 11.5', 'odd': '1.25'},
#         {'value': 'Over 8.5', 'odd': '1.67'},
#         {'value': 'Under 8.5', 'odd': '2.10'},
#         {'value': 'Over 12.5', 'odd': '4.75'},
#         {'value': 'Under 12.5', 'odd': '1.15'}]}]},
#     {'id': 22,
#      'name': 'Tipico',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '9.50'},
#         {'value': 'Draw', 'odd': '4.30'},
#         {'value': 'Away', 'odd': '1.30'}]},
#       {'id': 2,
#        'name': 'Home/Away',
#        'values': [{'value': 'Home', 'odd': '6.50'},
#         {'value': 'Away', 'odd': '1.07'}]},
#       {'id': 5,
#        'name': 'Goals Over/Under',
#        'values': [{'value': 'Over 3.5', 'odd': '3.00'},
#         {'value': 'Under 3.5', 'odd': '1.33'},
#         {'value': 'Over 1.5', 'odd': '1.25'},
#         {'value': 'Under 1.5', 'odd': '3.50'},
#         {'value': 'Over 4.5', 'odd': '6.20'},
#         {'value': 'Under 4.5', 'odd': '1.08'},
#         {'value': 'Over 2.5', 'odd': '1.87'},
#         {'value': 'Under 2.5', 'odd': '1.83'},
#         {'value': 'Over 0.5', 'odd': '1.01'},
#         {'value': 'Under 0.5', 'odd': '10.50'},
#         {'value': 'Over 5.5', 'odd': '12.00'},
#         {'value': 'Under 5.5', 'odd': '1.03'}]},
#       {'id': 6,
#        'name': 'Goals Over/Under First Half',
#        'values': [{'value': 'Over 1.5', 'odd': '2.75'},
#         {'value': 'Under 1.5', 'odd': '1.37'},
#         {'value': 'Over 2.5', 'odd': '5.80'},
#         {'value': 'Under 2.5', 'odd': '1.08'},
#         {'value': 'Over 0.5', 'odd': '1.35'},
#         {'value': 'Under 0.5', 'odd': '2.80'}]},
#       {'id': 26,
#        'name': 'Goals Over/Under - Second Half',
#        'values': [{'value': 'Over 1.5', 'odd': '2.05'},
#         {'value': 'Under 1.5', 'odd': '1.65'},
#         {'value': 'Over 2.5', 'odd': '4.40'},
#         {'value': 'Under 2.5', 'odd': '1.16'},
#         {'value': 'Over 0.5', 'odd': '1.22'},
#         {'value': 'Under 0.5', 'odd': '3.70'}]},
#       {'id': 7,
#        'name': 'HT/FT Double',
#        'values': [{'value': 'Home/Draw', 'odd': '20.00'},
#         {'value': 'Home/Away', 'odd': '25.00'},
#         {'value': 'Draw/Away', 'odd': '3.50'},
#         {'value': 'Draw/Draw', 'odd': '6.20'},
#         {'value': 'Home/Home', 'odd': '14.00'},
#         {'value': 'Draw/Home', 'odd': '15.00'},
#         {'value': 'Away/Home', 'odd': '100.00'},
#         {'value': 'Away/Draw', 'odd': '20.00'},
#         {'value': 'Away/Away', 'odd': '1.93'}]},
#       {'id': 8,
#        'name': 'Both Teams Score',
#        'values': [{'value': 'Yes', 'odd': '2.10'},
#         {'value': 'No', 'odd': '1.62'}]},
#       {'id': 9,
#        'name': 'Handicap Result',
#        'values': [{'value': 'Home +1', 'odd': '3.10'},
#         {'value': 'Away +1', 'odd': '1.93'},
#         {'value': 'Draw +1', 'odd': '3.40'},
#         {'value': 'Home +2', 'odd': '1.55'},
#         {'value': 'Draw +2', 'odd': '4.10'},
#         {'value': 'Away +2', 'odd': '4.00'},
#         {'value': 'Home +3', 'odd': '1.13'},
#         {'value': 'Draw +3', 'odd': '6.70'},
#         {'value': 'Away +3', 'odd': '9.50'}]},
#       {'id': 10,
#        'name': 'Exact Score',
#        'values': [{'value': '1:0', 'odd': '23.00'},
#         {'value': '2:0', 'odd': '55.00'},
#         {'value': '2:1', 'odd': '30.00'},
#         {'value': '3:0', 'odd': '200.00'},
#         {'value': '3:1', 'odd': '90.00'},
#         {'value': '3:2', 'odd': '60.00'},
#         {'value': '4:0', 'odd': '250.00'},
#         {'value': '4:1', 'odd': '250.00'},
#         {'value': '4:2', 'odd': '250.00'},
#         {'value': '4:3', 'odd': '250.00'},
#         {'value': '5:0', 'odd': '250.00'},
#         {'value': '5:1', 'odd': '250.00'},
#         {'value': '5:2', 'odd': '250.00'},
#         {'value': '5:3', 'odd': '250.00'},
#         {'value': '5:4', 'odd': '250.00'},
#         {'value': '6:0', 'odd': '250.00'},
#         {'value': '6:1', 'odd': '250.00'},
#         {'value': '6:2', 'odd': '250.00'},
#         {'value': '0:0', 'odd': '11.00'},
#         {'value': '1:1', 'odd': '8.00'},
#         {'value': '2:2', 'odd': '27.00'},
#         {'value': '3:3', 'odd': '120.00'},
#         {'value': '4:4', 'odd': '250.00'},
#         {'value': '0:1', 'odd': '5.50'},
#         {'value': '0:2', 'odd': '5.50'},
#         {'value': '0:3', 'odd': '9.00'},
#         {'value': '0:4', 'odd': '20.00'},
#         {'value': '0:5', 'odd': '40.00'},
#         {'value': '0:6', 'odd': '90.00'},
#         {'value': '1:2', 'odd': '7.80'},
#         {'value': '1:3', 'odd': '10.50'},
#         {'value': '1:4', 'odd': '27.00'},
#         {'value': '1:5', 'odd': '55.00'},
#         {'value': '1:6', 'odd': '150.00'},
#         {'value': '2:3', 'odd': '30.00'},
#         {'value': '2:4', 'odd': '70.00'},
#         {'value': '2:5', 'odd': '150.00'},
#         {'value': '2:6', 'odd': '250.00'},
#         {'value': '3:4', 'odd': '250.00'},
#         {'value': '3:5', 'odd': '250.00'},
#         {'value': '4:5', 'odd': '250.00'},
#         {'value': '4:6', 'odd': '250.00'},
#         {'value': '3:6', 'odd': '250.00'},
#         {'value': '6:3', 'odd': '250.00'},
#         {'value': '5:5', 'odd': '250.00'},
#         {'value': '6:6', 'odd': '250.00'},
#         {'value': '6:5', 'odd': '250.00'},
#         {'value': '5:6', 'odd': '250.00'},
#         {'value': '6:4', 'odd': '250.00'}]},
#       {'id': 11,
#        'name': 'Highest Scoring Half',
#        'values': [{'value': 'Draw', 'odd': '3.30'},
#         {'value': '1st Half', 'odd': '3.10'},
#         {'value': '2nd Half', 'odd': '1.95'}]},
#       {'id': 12,
#        'name': 'Double Chance',
#        'values': [{'value': 'Home/Draw', 'odd': '3.00'},
#         {'value': 'Home/Away', 'odd': '1.13'},
#         {'value': 'Draw/Away', 'odd': '1.01'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.80'},
#         {'value': 'Draw', 'odd': '2.35'},
#         {'value': 'Away', 'odd': '1.72'}]},
#       {'id': 16,
#        'name': 'Total - Home',
#        'values': [{'value': 'Over 1.5', 'odd': '5.30'},
#         {'value': 'Under 1.5', 'odd': '1.11'},
#         {'value': 'Over 2.5', 'odd': '10.00'},
#         {'value': 'Under 2.5', 'odd': '1.01'},
#         {'value': 'Over 0.5', 'odd': '1.97'},
#         {'value': 'Under 0.5', 'odd': '1.72'}]},
#       {'id': 17,
#        'name': 'Total - Away',
#        'values': [{'value': 'Over 3.5', 'odd': '6.20'},
#         {'value': 'Under 3.5', 'odd': '1.07'},
#         {'value': 'Over 1.5', 'odd': '1.52'},
#         {'value': 'Under 1.5', 'odd': '2.30'},
#         {'value': 'Over 2.5', 'odd': '2.95'},
#         {'value': 'Under 2.5', 'odd': '1.32'},
#         {'value': 'Over 0.5', 'odd': '1.10'},
#         {'value': 'Under 0.5', 'odd': '5.50'}]},
#       {'id': 34,
#        'name': 'Both Teams Score - First Half',
#        'values': [{'value': 'Yes', 'odd': '5.50'},
#         {'value': 'No', 'odd': '1.11'}]},
#       {'id': 35,
#        'name': 'Both Teams To Score - Second Half',
#        'values': [{'value': 'Yes', 'odd': '4.20'},
#         {'value': 'No', 'odd': '1.18'}]},
#       {'id': 21,
#        'name': 'Odd/Even',
#        'values': [{'value': 'Odd', 'odd': '1.87'},
#         {'value': 'Even', 'odd': '1.83'}]},
#       {'id': 25,
#        'name': 'Result/Total Goals',
#        'values': [{'value': 'Home/Over 2.5', 'odd': '16.00'},
#         {'value': 'Draw/Over 2.5', 'odd': '23.00'},
#         {'value': 'Away/Over 2.5', 'odd': '2.05'},
#         {'value': 'Home/Under 2.5', 'odd': '17.00'},
#         {'value': 'Draw/Under 2.5', 'odd': '5.00'},
#         {'value': 'Away/Under 2.5', 'odd': '2.95'}]},
#       {'id': 43,
#        'name': 'Home Team Score a Goal',
#        'values': [{'value': 'Yes', 'odd': '1.90'},
#         {'value': 'No', 'odd': '1.80'}]},
#       {'id': 44,
#        'name': 'Away Team Score a Goal',
#        'values': [{'value': 'Yes', 'odd': '1.07'},
#         {'value': 'No', 'odd': '6.50'}]},
#       {'id': 114,
#        'name': 'Home Team Score a Goal (1st Half)',
#        'values': [{'value': 'Yes', 'odd': '3.60'},
#         {'value': 'No', 'odd': '1.25'}]},
#       {'id': 115,
#        'name': 'Home Team Score a Goal (2nd Half)',
#        'values': [{'value': 'Yes', 'odd': '2.95'},
#         {'value': 'No', 'odd': '1.35'}]},
#       {'id': 116,
#        'name': 'Away Team Score a Goal (1st Half)',
#        'values': [{'value': 'Yes', 'odd': '1.60'},
#         {'value': 'No', 'odd': '2.20'}]},
#       {'id': 117,
#        'name': 'Away Team Score a Goal (2nd Half)',
#        'values': [{'value': 'Yes', 'odd': '1.40'},
#         {'value': 'No', 'odd': '2.75'}]}]},
#     {'id': 20,
#      'name': 'Betcris',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '7.60'},
#         {'value': 'Draw', 'odd': '4.32'},
#         {'value': 'Away', 'odd': '1.39'}]},
#       {'id': 2,
#        'name': 'Home/Away',
#        'values': [{'value': 'Home', 'odd': '5.35'},
#         {'value': 'Away', 'odd': '1.12'}]},
#       {'id': 5,
#        'name': 'Goals Over/Under',
#        'values': [{'value': 'Over 3.5', 'odd': '3.33'},
#         {'value': 'Under 3.5', 'odd': '1.30'},
#         {'value': 'Over 1.5', 'odd': '1.31'},
#         {'value': 'Under 1.5', 'odd': '3.28'},
#         {'value': 'Over 2.5', 'odd': '1.94'},
#         {'value': 'Under 2.5', 'odd': '1.80'}]},
#       {'id': 6,
#        'name': 'Goals Over/Under First Half',
#        'values': [{'value': 'Over 1.5', 'odd': '2.81'},
#         {'value': 'Under 1.5', 'odd': '1.38'},
#         {'value': 'Over 2.5', 'odd': '6.50'},
#         {'value': 'Under 2.5', 'odd': '1.08'},
#         {'value': 'Over 0.5', 'odd': '1.39'},
#         {'value': 'Under 0.5', 'odd': '2.76'}]},
#       {'id': 8,
#        'name': 'Both Teams Score',
#        'values': [{'value': 'Yes', 'odd': '2.23'},
#         {'value': 'No', 'odd': '1.59'}]},
#       {'id': 12,
#        'name': 'Double Chance',
#        'values': [{'value': 'Home/Draw', 'odd': '2.52'},
#         {'value': 'Home/Away', 'odd': '1.18'},
#         {'value': 'Draw/Away', 'odd': '1.09'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '7.25'},
#         {'value': 'Draw', 'odd': '2.24'},
#         {'value': 'Away', 'odd': '1.90'}]}]},
#     {'id': 9,
#      'name': 'Dafabet',
#      'bets': [{'id': 1,
#        'name': 'Match Winner',
#        'values': [{'value': 'Home', 'odd': '7.20'},
#         {'value': 'Draw', 'odd': '4.30'},
#         {'value': 'Away', 'odd': '1.38'}]},
#       {'id': 4,
#        'name': 'Asian Handicap',
#        'values': [{'value': 'Home +0.75', 'odd': '2.66'},
#         {'value': 'Away +0.75', 'odd': '1.50'},
#         {'value': 'Home +1', 'odd': '2.29'},
#         {'value': 'Away +1', 'odd': '1.67'},
#         {'value': 'Home +1.5', 'odd': '1.70'},
#         {'value': 'Away +1.5', 'odd': '2.25'},
#         {'value': 'Home +1.25', 'odd': '1.94'},
#         {'value': 'Away +1.25', 'odd': '1.96'},
#         {'value': 'Home +1.75', 'odd': '1.53'},
#         {'value': 'Away +1.75', 'odd': '2.58'}]},
#       {'id': 5,
#        'name': 'Goals Over/Under',
#        'values': [{'value': 'Over 2.5', 'odd': '1.96'},
#         {'value': 'Under 2.5', 'odd': '1.92'},
#         {'value': 'Over 2.25', 'odd': '1.75'},
#         {'value': 'Under 2.25', 'odd': '2.14'},
#         {'value': 'Over 2.75', 'odd': '2.21'},
#         {'value': 'Under 2.75', 'odd': '1.70'},
#         {'value': 'Over 3.0', 'odd': '2.63'},
#         {'value': 'Under 3.0', 'odd': '1.49'},
#         {'value': 'Over 2.0', 'odd': '1.46'},
#         {'value': 'Under 2.0', 'odd': '2.72'}]},
#       {'id': 6,
#        'name': 'Goals Over/Under First Half',
#        'values': [{'value': 'Over 0.5', 'odd': '1.40'},
#         {'value': 'Under 0.5', 'odd': '2.92'},
#         {'value': 'Over 1.25', 'odd': '2.40'},
#         {'value': 'Under 1.25', 'odd': '1.59'},
#         {'value': 'Over 0.75', 'odd': '1.60'},
#         {'value': 'Under 0.75', 'odd': '2.38'},
#         {'value': 'Over 1.0', 'odd': '1.91'},
#         {'value': 'Under 1.0', 'odd': '1.97'}]},
#       {'id': 13,
#        'name': 'First Half Winner',
#        'values': [{'value': 'Home', 'odd': '6.40'},
#         {'value': 'Draw', 'odd': '2.30'},
#         {'value': 'Away', 'odd': '1.89'}]},
#       {'id': 19,
#        'name': 'Asian Handicap First Half',
#        'values': [{'value': 'Home +0.25', 'odd': '2.53'},
#         {'value': 'Away +0.25', 'odd': '1.53'},
#         {'value': 'Home +0.5', 'odd': '1.99'},
#         {'value': 'Away +0.5', 'odd': '1.89'},
#         {'value': 'Home +0.75', 'odd': '1.60'},
#         {'value': 'Away +0.75', 'odd': '2.38'},
#         {'value': 'Home +1', 'odd': '1.34'},
#         {'value': 'Away +1', 'odd': '3.17'}]}]}]}]}

# %% [markdown]
# ###
